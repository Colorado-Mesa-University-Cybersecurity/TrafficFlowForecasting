# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import matplotlib.pyplot as plt
from rff.layers import GaussianEncoding
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
if torch.cuda.is_available():
    device_in_use = torch.device("cuda")
    print("GPU is available and being used")
else:
    device_in_use = torch.device("cpu")
    print("GPU is not available, using CPU instead")
# Out:
# GPU is not available, using CPU instead

# %% [markdown]
# Using Scenario B, 15s dataset for classifcation on traffic type (7 classes)

# %%
# df = pd.read_csv(r"C:\Users\smbm2\projects\TrafficFlowForecasting\warins_experiments\data\Scenario B\TimeBasedFeatures-Dataset-15s-AllinOne.csv") # personal
df = pd.read_csv(r"C:\python\research\csv_datasets\Scenario B\TimeBasedFeatures-Dataset-15s-AllinOne.csv") # for IR

df.head()
# Out:
#    Unnamed: 0    duration  total_fiat  total_biat   min_fiat   min_biat  \
# 0           0   9368711.0        16.0         4.0  1564818.0  1549373.0
# 1           1   7340238.0        18.0         4.0  1567554.0  1527893.0
# 2           2   4644225.0        29.0        15.0  1270547.0  1079974.0
# 3           3   4978735.0        19.0         8.0  2492050.0  2457286.0
# 4           4  11838189.0        19.0        10.0  3094089.0  3093543.0
#
#         max_fiat       max_biat      mean_fiat      mean_biat  ...  \
# 0  190205.285714  203290.456522  389822.391917  370323.719754  ...
# 1  165686.977273  186914.846154  317267.548742  304370.651301  ...
# 2  165865.178571  195302.130435  329473.126261  300492.588227  ...
# 3  239543.250000  276596.388889  612435.304238  628339.573544  ...
# 4  243766.500000  295954.725000  599721.781709  625632.703972  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  267600.198443   1871488.0  1.983656e+06   2195089.0  1.832197e+05
# 1  221462.862028   1491627.0  3.572433e+06   5653239.0  2.942704e+06
# 2  217475.425246   1758922.0  1.758922e+06   1758922.0  0.000000e+00
# 3  436959.716436   1710925.0  2.382905e+06   3054885.0  9.503232e+05
# 4  436129.639296   1747431.0  2.400446e+06   3240696.0  6.232744e+05
#
#     min_idle  mean_idle   max_idle       std_idle  class1
# 0  1234883.0  1420565.0  1523088.0  161096.539275    CHAT
# 1  1131498.0  1324636.0  1517774.0  273138.379008    CHAT
# 2  1079974.0  1079974.0  1079974.0       0.000000    CHAT
# 3  1346073.0  1894031.5  2441990.0  774930.342317    CHAT
# 4  1394455.0  1983227.0  3042717.0  725987.829075    CHAT
#
# [5 rows x 25 columns]

# %%
df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#      duration  total_fiat  total_biat   min_fiat   min_biat       max_fiat  \
# 0   9368711.0        16.0         4.0  1564818.0  1549373.0  190205.285714
# 1   7340238.0        18.0         4.0  1567554.0  1527893.0  165686.977273
# 2   4644225.0        29.0        15.0  1270547.0  1079974.0  165865.178571
# 3   4978735.0        19.0         8.0  2492050.0  2457286.0  239543.250000
# 4  11838189.0        19.0        10.0  3094089.0  3093543.0  243766.500000
#
#         max_biat      mean_fiat      mean_biat  flowPktsPerSecond  ...  \
# 0  203290.456522  389822.391917  370323.719754          10.353612  ...
# 1  186914.846154  317267.548742  304370.651301          11.580006  ...
# 2  195302.130435  329473.126261  300492.588227          11.412022  ...
# 3  276596.388889  612435.304238  628339.573544           8.034169  ...
# 4  295954.725000  599721.781709  625632.703972           7.602514  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  267600.198443   1871488.0  1.983656e+06   2195089.0  1.832197e+05
# 1  221462.862028   1491627.0  3.572433e+06   5653239.0  2.942704e+06
# 2  217475.425246   1758922.0  1.758922e+06   1758922.0  0.000000e+00
# 3  436959.716436   1710925.0  2.382905e+06   3054885.0  9.503232e+05
# 4  436129.639296   1747431.0  2.400446e+06   3240696.0  6.232744e+05
#
#     min_idle  mean_idle   max_idle       std_idle  class1
# 0  1234883.0  1420565.0  1523088.0  161096.539275    CHAT
# 1  1131498.0  1324636.0  1517774.0  273138.379008    CHAT
# 2  1079974.0  1079974.0  1079974.0       0.000000    CHAT
# 3  1346073.0  1894031.5  2441990.0  774930.342317    CHAT
# 4  1394455.0  1983227.0  3042717.0  725987.829075    CHAT
#
# [5 rows x 24 columns]

# %%
le = LabelEncoder()
df['class1'] = le.fit_transform(df['class1'])
df.head()
# Out:
#      duration  total_fiat  total_biat   min_fiat   min_biat       max_fiat  \
# 0   9368711.0        16.0         4.0  1564818.0  1549373.0  190205.285714
# 1   7340238.0        18.0         4.0  1567554.0  1527893.0  165686.977273
# 2   4644225.0        29.0        15.0  1270547.0  1079974.0  165865.178571
# 3   4978735.0        19.0         8.0  2492050.0  2457286.0  239543.250000
# 4  11838189.0        19.0        10.0  3094089.0  3093543.0  243766.500000
#
#         max_biat      mean_fiat      mean_biat  flowPktsPerSecond  ...  \
# 0  203290.456522  389822.391917  370323.719754          10.353612  ...
# 1  186914.846154  317267.548742  304370.651301          11.580006  ...
# 2  195302.130435  329473.126261  300492.588227          11.412022  ...
# 3  276596.388889  612435.304238  628339.573544           8.034169  ...
# 4  295954.725000  599721.781709  625632.703972           7.602514  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  267600.198443   1871488.0  1.983656e+06   2195089.0  1.832197e+05
# 1  221462.862028   1491627.0  3.572433e+06   5653239.0  2.942704e+06
# 2  217475.425246   1758922.0  1.758922e+06   1758922.0  0.000000e+00
# 3  436959.716436   1710925.0  2.382905e+06   3054885.0  9.503232e+05
# 4  436129.639296   1747431.0  2.400446e+06   3240696.0  6.232744e+05
#
#     min_idle  mean_idle   max_idle       std_idle  class1
# 0  1234883.0  1420565.0  1523088.0  161096.539275       1
# 1  1131498.0  1324636.0  1517774.0  273138.379008       1
# 2  1079974.0  1079974.0  1079974.0       0.000000       1
# 3  1346073.0  1894031.5  2441990.0  774930.342317       1
# 4  1394455.0  1983227.0  3042717.0  725987.829075       1
#
# [5 rows x 24 columns]

# %%
df['class1'].value_counts()
# Out:
# 6    5097
# 0    5000
# 2    2950
# 1    2086
# 4    1928
# 5     957
# 3     740
# Name: class1, dtype: int64

# %%
df.isna().any()
# Out:
# duration              False
# total_fiat            False
# total_biat            False
# min_fiat              False
# min_biat              False
# max_fiat              False
# max_biat              False
# mean_fiat             False
# mean_biat             False
# flowPktsPerSecond     False
# flowBytesPerSecond    False
# min_flowiat           False
# max_flowiat           False
# mean_flowiat          False
# std_flowiat           False
# min_active            False
# mean_active           False
# max_active            False
# std_active            False
# min_idle              False
# mean_idle             False
# max_idle              False
# std_idle              False
# class1                False
# dtype: bool

# %%
class vpnDataset(Dataset):
    def __init__(self, df, target = 'class1'):
        
        self.n = df.shape[0]
        
        self.y = df[target].astype(np.int64).values

        self.scalar = StandardScaler()
        self.x = self.scalar.fit_transform(df.drop(columns=[target])).astype(np.float32)


    def __len__(self):
        return self.n
    
    def __getitem__(self, index):
        return self.x[index], self.y[index]

# %%
vpn_dataset = vpnDataset(df)

# %%
len(vpn_dataset)
# Out:
# 18758

# %%
vpn_dataset[:5]
# Out:
# (array([[-0.02940687, -0.27134442, -0.26942125, -0.16471212, -0.13596162,
#          -0.25900155, -0.2878839 , -0.10492614, -0.09658284, -0.10794687,
#          -0.05048493, -0.09395073, -0.16820657, -0.27002892, -0.21715535,
#          -0.10293681, -0.12181747, -0.13542001, -0.11346608, -0.13107145,
#          -0.14135256, -0.15893458, -0.10484384],
#         [-0.17042781, -0.27134353, -0.26942125, -0.16445452, -0.13818699,
#          -0.26680553, -0.29444486, -0.12165756, -0.12279288, -0.10788272,
#          -0.05053715, -0.09395073, -0.1685897 , -0.2772968 , -0.23021066,
#          -0.13122302, -0.00466192,  0.11156006,  0.8672013 , -0.13881978,
#          -0.14847216, -0.15931685, -0.06462058],
#         [-0.35785663, -0.2713386 , -0.2694165 , -0.19241899, -0.18459238,
#          -0.2667488 , -0.29108447, -0.1188429 , -0.12433404, -0.1078915 ,
#          -0.05055733, -0.09392591, -0.20015396, -0.27592382, -0.23133896,
#          -0.111319  , -0.13838926, -0.16657093, -0.17857882, -0.14268132,
#          -0.16663031, -0.19081059, -0.16267785],
#         [-0.33460125, -0.27134308, -0.26941952, -0.07740927, -0.04189983,
#          -0.24329768, -0.25851357, -0.05359077,  0.00595383, -0.10806821,
#          -0.05058475, -0.0939417 , -0.10195606, -0.24861813, -0.16923234,
#          -0.11489308, -0.09237708, -0.07401363,  0.15914768, -0.12273817,
#          -0.10621314, -0.09283213,  0.11552382],
#         [ 0.14227307, -0.27134308, -0.26941866, -0.02072472,  0.0240178 ,
#          -0.24195345, -0.25075758, -0.05652256,  0.00487811, -0.1080908 ,
#          -0.05071079, -0.09393719, -0.05864517, -0.24480616, -0.16946721,
#          -0.11217467, -0.09108362, -0.06074306,  0.04292085, -0.11911211,
#          -0.0995933 , -0.04961802,  0.09795336]], dtype=float32),
#  array([1, 1, 1, 1, 1], dtype=int64))

# %%
train_size = int(0.7*len(vpn_dataset))
print(train_size)
test_size = len(vpn_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(vpn_dataset, [train_size, test_size])
print(len(train_dataset), len(test_dataset))
# Out:
# 13130
# 13130 5628

# %%
batch_size = 256
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
#to be sure that the distributions of classes are close to the same (random_split is actually randomly splitting)

from collections import Counter

train_labels = []
test_labels = []
for input, labels in train_dataloader:
    train_labels.extend(labels.flatten().tolist())

for input, labels in test_dataloader:
    test_labels.extend(labels.flatten().tolist())

train_distribution = Counter(train_labels)
test_distribution = Counter(test_labels)


plt.figure(figsize=(10, 6))

# Plotting training distribution
plt.subplot(1, 2, 1)
plt.bar(train_distribution.keys(), train_distribution.values())
plt.title('Training Class Distribution')
plt.xlabel('Class Labels')
plt.ylabel('Frequency')

# Plotting testing distribution
plt.subplot(1, 2, 2)
plt.bar(test_distribution.keys(), test_distribution.values())
plt.title('Testing Class Distribution')
plt.xlabel('Class Labels')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
for batch_idx, (inputs, targets) in enumerate(train_dataloader):
    # `inputs` will contain the input features for the current batch
    # `targets` will contain the corresponding target labels

    # Print the batch index and the sizes of inputs and targets
    print(f"Batch Index: {batch_idx}")
    print("Input sizes:", inputs.size())
    print("Target sizes:", targets.size())

    # You can also print the actual data if you want to see the values
    print("Inputs:")
    print(inputs)
    print("Targets:")
    print(targets)
# Out:
# Batch Index: 0
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3587, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.5729, -0.2713, -0.2694,  ..., -0.1616, -0.1860, -0.1627],
#         [ 0.0291, -0.2712, -0.2694,  ...,  0.4591,  0.4157, -0.1627],
#         ...,
#         [ 0.0199,  4.2042,  4.0457,  ...,  0.4954,  0.4509, -0.1627],
#         [-0.6647, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0199,  4.2040,  4.0458,  ...,  0.4954,  0.4509, -0.1627]])
# Targets:
# tensor([2, 0, 0, 0, 6, 6, 2, 4, 6, 6, 4, 0, 2, 2, 1, 0, 0, 2, 1, 0, 0, 0, 4, 6,
#         6, 6, 1, 6, 0, 0, 0, 6, 0, 6, 6, 6, 6, 4, 0, 6, 4, 6, 1, 2, 4, 6, 6, 0,
#         0, 6, 4, 0, 6, 1, 2, 4, 1, 1, 6, 6, 2, 4, 0, 1, 0, 2, 2, 1, 6, 2, 6, 0,
#         3, 0, 0, 4, 4, 1, 0, 5, 2, 3, 2, 1, 2, 2, 0, 2, 0, 4, 2, 6, 6, 2, 1, 2,
#         5, 0, 6, 2, 3, 1, 6, 6, 0, 1, 0, 6, 4, 4, 4, 0, 4, 6, 1, 0, 0, 1, 4, 4,
#         0, 6, 6, 2, 6, 3, 5, 6, 2, 2, 6, 1, 4, 6, 1, 6, 0, 0, 6, 0, 1, 6, 0, 2,
#         4, 6, 2, 4, 3, 5, 6, 0, 0, 6, 0, 5, 6, 6, 5, 6, 3, 6, 2, 1, 6, 0, 5, 2,
#         6, 0, 0, 1, 2, 1, 0, 6, 1, 0, 6, 6, 4, 0, 4, 6, 6, 0, 6, 1, 6, 0, 6, 0,
#         0, 0, 6, 0, 6, 2, 6, 2, 1, 4, 6, 4, 0, 6, 1, 0, 3, 6, 6, 5, 2, 6, 2, 6,
#         6, 4, 6, 0, 1, 2, 0, 2, 6, 5, 6, 2, 6, 6, 1, 4, 1, 0, 6, 6, 6, 1, 6, 0,
#         6, 0, 6, 5, 0, 2, 4, 6, 0, 2, 2, 6, 1, 6, 4, 6])
# Batch Index: 1
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.4414, -0.1930, -0.2692,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3117, -0.2712, -0.2672,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6772, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2504, -0.2567, -0.2589,  ..., -0.1185, -0.1315, -0.0560]])
# Targets:
# tensor([1, 4, 2, 6, 0, 2, 6, 0, 1, 4, 0, 2, 2, 4, 1, 1, 1, 0, 6, 2, 2, 0, 5, 0,
#         1, 1, 6, 6, 4, 0, 0, 2, 6, 2, 2, 4, 6, 6, 6, 1, 6, 5, 1, 6, 2, 0, 2, 0,
#         4, 0, 2, 4, 0, 5, 0, 6, 6, 5, 1, 1, 6, 1, 6, 6, 2, 0, 0, 6, 3, 1, 1, 6,
#         3, 0, 0, 0, 5, 0, 0, 0, 1, 1, 6, 6, 4, 6, 6, 6, 2, 4, 6, 5, 6, 1, 0, 0,
#         6, 6, 0, 0, 5, 1, 3, 0, 2, 4, 2, 1, 5, 0, 6, 4, 0, 6, 1, 0, 2, 3, 0, 6,
#         6, 6, 6, 6, 0, 1, 0, 0, 4, 2, 6, 0, 0, 0, 0, 4, 4, 6, 5, 2, 0, 0, 6, 2,
#         6, 2, 4, 2, 1, 6, 4, 0, 6, 1, 0, 1, 6, 2, 0, 5, 1, 6, 0, 2, 2, 0, 1, 2,
#         6, 6, 6, 3, 0, 0, 4, 3, 0, 0, 6, 0, 0, 1, 1, 2, 6, 5, 0, 1, 6, 2, 6, 5,
#         2, 1, 6, 0, 5, 0, 0, 0, 0, 0, 6, 4, 2, 1, 0, 0, 2, 6, 6, 6, 4, 6, 6, 0,
#         2, 6, 1, 5, 6, 2, 6, 6, 0, 2, 3, 2, 0, 4, 2, 2, 4, 6, 6, 0, 1, 2, 6, 2,
#         2, 6, 4, 6, 0, 0, 6, 4, 6, 3, 5, 2, 2, 1, 1, 1])
# Batch Index: 2
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.2334, -0.2713, -0.2694,  ...,  0.2036,  0.4437,  1.7825],
#         [ 0.2571, -0.2713, -0.2694,  ...,  0.0524,  0.2624,  0.8964],
#         [-0.6284, -0.2709, -0.1613,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.0219, -0.2713, -0.2694,  ...,  0.4783,  0.4343, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0199,  4.2040,  4.0458,  ...,  0.4954,  0.4509, -0.1627]])
# Targets:
# tensor([0, 0, 2, 1, 6, 1, 6, 6, 4, 6, 3, 6, 6, 6, 4, 6, 6, 0, 1, 4, 2, 3, 6, 6,
#         4, 2, 1, 6, 0, 0, 6, 6, 1, 2, 2, 0, 0, 1, 6, 4, 2, 1, 4, 2, 0, 6, 4, 6,
#         2, 1, 1, 6, 1, 6, 1, 0, 6, 4, 6, 2, 2, 6, 1, 1, 6, 5, 4, 5, 0, 1, 0, 6,
#         0, 0, 6, 6, 6, 4, 2, 5, 2, 6, 0, 6, 5, 0, 4, 2, 6, 6, 0, 4, 6, 2, 0, 5,
#         2, 1, 6, 0, 6, 4, 6, 1, 6, 6, 0, 5, 0, 1, 4, 2, 2, 2, 4, 6, 4, 6, 0, 2,
#         6, 0, 4, 6, 3, 5, 6, 0, 6, 6, 6, 1, 6, 5, 6, 5, 4, 4, 0, 6, 0, 1, 1, 0,
#         1, 2, 1, 0, 1, 5, 3, 1, 6, 0, 0, 0, 0, 0, 6, 1, 0, 6, 0, 2, 0, 3, 2, 6,
#         6, 0, 5, 2, 0, 6, 3, 6, 1, 2, 2, 2, 6, 0, 0, 6, 2, 0, 6, 1, 6, 0, 6, 0,
#         2, 4, 1, 6, 6, 6, 6, 2, 6, 2, 0, 4, 0, 1, 1, 2, 6, 0, 2, 6, 6, 0, 1, 6,
#         0, 5, 2, 3, 6, 4, 0, 5, 5, 6, 2, 6, 6, 6, 0, 0, 6, 5, 0, 6, 1, 3, 0, 0,
#         3, 6, 1, 0, 0, 6, 0, 2, 6, 3, 6, 6, 6, 0, 4, 6])
# Batch Index: 3
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.5259, -0.2712, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3413, -0.2714, -0.2694,  ...,  0.0713,  0.2868,  0.9469],
#         [-0.6807, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.2928, -0.2333, -0.2643,  ...,  0.0794,  0.1756,  0.4602],
#         [ 0.3224,  0.1566,  0.1434,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.5326, -0.2713, -0.2694,  ..., -0.1032, -0.1293, -0.1627]])
# Targets:
# tensor([3, 0, 2, 2, 6, 6, 2, 4, 0, 2, 2, 6, 6, 6, 4, 0, 5, 2, 6, 0, 2, 6, 2, 4,
#         6, 4, 0, 1, 0, 0, 6, 0, 0, 2, 2, 6, 2, 2, 1, 0, 6, 6, 1, 6, 2, 0, 1, 2,
#         6, 6, 6, 3, 6, 2, 1, 6, 2, 4, 4, 4, 1, 6, 0, 0, 6, 4, 6, 3, 2, 2, 0, 0,
#         1, 1, 2, 4, 3, 4, 6, 6, 1, 1, 6, 2, 6, 1, 6, 4, 0, 2, 0, 0, 0, 3, 5, 6,
#         6, 6, 1, 0, 6, 4, 0, 2, 0, 4, 6, 4, 0, 2, 0, 4, 0, 4, 1, 1, 4, 6, 4, 6,
#         1, 6, 6, 0, 0, 0, 1, 3, 0, 2, 4, 6, 4, 0, 5, 1, 2, 0, 6, 0, 0, 0, 6, 6,
#         1, 1, 4, 6, 2, 0, 3, 0, 2, 6, 2, 0, 6, 1, 0, 0, 2, 6, 6, 6, 4, 6, 0, 2,
#         6, 6, 6, 2, 1, 4, 0, 4, 2, 5, 1, 1, 5, 2, 2, 0, 6, 6, 2, 5, 1, 2, 6, 2,
#         4, 1, 3, 6, 2, 1, 2, 4, 6, 6, 0, 6, 0, 6, 6, 2, 6, 2, 0, 5, 0, 6, 0, 2,
#         0, 6, 6, 6, 6, 2, 0, 4, 1, 6, 4, 1, 0, 2, 6, 0, 2, 2, 2, 2, 6, 0, 6, 0,
#         0, 0, 6, 6, 6, 6, 4, 6, 6, 6, 6, 6, 0, 0, 6, 0])
# Batch Index: 4
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3277, -0.2671, -0.2653,  ..., -0.1279, -0.1410, -0.1023],
#         [ 0.2288, -0.2713, -0.2694,  ...,  0.0799,  0.1811,  0.7754],
#         [ 0.3020, -0.2380, -0.2568,  ...,  0.1846,  0.1573, -0.1079],
#         ...,
#         [-0.6633, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2859, -0.2713, -0.2694,  ...,  0.1615,  0.2746,  0.8768],
#         [ 0.3471, -0.2713, -0.2694,  ...,  0.3167,  0.2777, -0.1627]])
# Targets:
# tensor([1, 0, 1, 6, 4, 1, 6, 2, 6, 2, 6, 6, 6, 6, 1, 6, 1, 0, 0, 4, 6, 0, 1, 0,
#         2, 3, 6, 2, 4, 1, 2, 6, 3, 6, 6, 6, 4, 0, 6, 0, 4, 6, 1, 6, 0, 4, 2, 6,
#         0, 6, 3, 1, 6, 2, 2, 0, 5, 0, 2, 2, 6, 2, 4, 2, 0, 4, 4, 0, 0, 6, 0, 0,
#         3, 0, 6, 0, 2, 0, 0, 1, 6, 2, 2, 3, 0, 0, 2, 0, 6, 2, 4, 6, 6, 1, 2, 2,
#         5, 0, 0, 0, 0, 1, 6, 3, 4, 0, 4, 1, 1, 0, 5, 2, 2, 2, 0, 5, 0, 6, 4, 6,
#         6, 4, 4, 3, 1, 5, 2, 6, 4, 2, 3, 0, 0, 6, 2, 6, 0, 6, 0, 0, 0, 6, 5, 0,
#         6, 0, 6, 0, 0, 4, 0, 5, 6, 1, 0, 4, 6, 1, 0, 1, 1, 4, 1, 4, 0, 6, 0, 6,
#         6, 6, 0, 0, 0, 6, 1, 1, 4, 1, 0, 6, 1, 6, 0, 2, 0, 1, 1, 2, 6, 6, 6, 2,
#         4, 0, 2, 4, 6, 0, 2, 0, 6, 1, 6, 0, 6, 6, 0, 6, 1, 6, 0, 2, 0, 0, 0, 2,
#         0, 0, 0, 5, 5, 5, 4, 4, 2, 6, 0, 6, 4, 1, 6, 2, 0, 6, 5, 6, 1, 0, 2, 0,
#         5, 0, 6, 4, 2, 0, 6, 0, 1, 0, 6, 0, 4, 2, 1, 6])
# Batch Index: 5
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.0416, -0.2531, -0.2692,  ...,  0.1284,  0.2941,  1.2412],
#         [ 0.3222,  0.1566,  0.1432,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2280,  1.1013,  1.0357,  ...,  0.0765,  0.2317,  0.6448],
#         ...,
#         [-0.6634, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3615, -0.2713, -0.2694,  ...,  0.3264,  0.2871, -0.1627],
#         [ 0.3234,  0.1564,  0.1430,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([1, 6, 2, 0, 0, 2, 6, 6, 5, 0, 2, 6, 1, 6, 1, 0, 4, 3, 0, 6, 1, 2, 4, 0,
#         6, 1, 2, 1, 4, 4, 1, 0, 2, 0, 6, 4, 3, 2, 0, 6, 5, 0, 2, 4, 2, 2, 2, 0,
#         0, 2, 6, 5, 4, 5, 6, 5, 6, 2, 4, 6, 0, 6, 1, 2, 6, 4, 2, 0, 0, 1, 6, 6,
#         0, 6, 6, 0, 6, 4, 0, 0, 6, 6, 6, 2, 6, 4, 6, 6, 0, 1, 4, 0, 6, 6, 6, 2,
#         0, 6, 1, 0, 6, 5, 6, 2, 3, 6, 1, 5, 2, 3, 1, 2, 4, 0, 6, 5, 6, 2, 2, 6,
#         5, 2, 6, 0, 3, 0, 1, 4, 1, 0, 0, 6, 2, 4, 6, 6, 2, 6, 0, 6, 2, 6, 2, 3,
#         6, 2, 1, 1, 0, 2, 0, 1, 0, 0, 6, 6, 2, 2, 0, 0, 0, 2, 6, 0, 0, 5, 6, 4,
#         6, 6, 0, 0, 2, 6, 0, 6, 2, 6, 2, 4, 4, 3, 0, 1, 2, 5, 0, 0, 0, 0, 2, 2,
#         0, 4, 5, 5, 4, 0, 2, 6, 3, 1, 4, 0, 1, 5, 0, 1, 0, 3, 6, 0, 0, 2, 0, 2,
#         6, 1, 2, 6, 0, 0, 2, 0, 6, 5, 1, 1, 5, 1, 1, 2, 3, 6, 2, 4, 6, 0, 0, 0,
#         0, 6, 6, 1, 3, 0, 2, 0, 0, 2, 6, 0, 0, 4, 6, 6])
# Batch Index: 6
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6766, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6614, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6607, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6688, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3606, -0.2713, -0.2659,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3609, -0.2713, -0.2694,  ...,  0.0136,  0.0829,  0.2824]])
# Targets:
# tensor([4, 4, 4, 3, 6, 3, 0, 6, 6, 1, 6, 1, 6, 0, 2, 2, 4, 0, 0, 6, 6, 4, 2, 1,
#         6, 2, 2, 6, 2, 1, 6, 5, 6, 2, 0, 4, 6, 4, 0, 6, 6, 6, 4, 3, 3, 6, 2, 6,
#         1, 6, 6, 2, 0, 1, 3, 5, 2, 0, 0, 0, 6, 1, 0, 6, 6, 0, 2, 6, 2, 0, 0, 0,
#         1, 6, 2, 1, 1, 4, 6, 0, 2, 2, 2, 1, 2, 6, 2, 0, 2, 3, 6, 1, 2, 3, 5, 0,
#         1, 6, 6, 6, 0, 5, 0, 5, 6, 1, 0, 0, 0, 5, 6, 6, 4, 6, 2, 6, 3, 5, 0, 0,
#         2, 0, 3, 3, 4, 5, 1, 0, 1, 2, 6, 6, 0, 0, 6, 2, 0, 1, 6, 0, 2, 0, 1, 6,
#         5, 2, 0, 0, 1, 1, 0, 6, 2, 3, 6, 2, 6, 6, 6, 6, 1, 1, 5, 6, 6, 4, 2, 2,
#         1, 0, 2, 2, 6, 6, 1, 2, 2, 0, 6, 6, 6, 4, 6, 0, 2, 1, 0, 4, 2, 6, 1, 0,
#         6, 2, 0, 6, 0, 2, 6, 4, 0, 0, 6, 6, 2, 0, 4, 6, 0, 4, 0, 6, 4, 0, 6, 0,
#         0, 2, 4, 6, 6, 6, 5, 6, 2, 5, 0, 5, 5, 0, 2, 4, 4, 4, 6, 0, 2, 6, 4, 0,
#         2, 6, 2, 0, 2, 1, 0, 0, 4, 6, 6, 1, 0, 1, 6, 0])
# Batch Index: 7
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3620, -0.2644, -0.2674,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6714, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3621, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6686, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3236,  0.1564,  0.1427,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([6, 4, 6, 4, 6, 6, 1, 3, 4, 5, 4, 6, 5, 6, 4, 0, 6, 1, 6, 2, 6, 1, 6, 6,
#         6, 2, 1, 6, 1, 4, 2, 3, 6, 5, 0, 0, 6, 2, 4, 0, 6, 2, 2, 6, 1, 6, 6, 0,
#         3, 0, 0, 2, 1, 1, 5, 6, 6, 0, 1, 2, 0, 2, 2, 4, 6, 2, 6, 2, 6, 6, 0, 4,
#         4, 4, 0, 6, 3, 1, 4, 0, 1, 2, 0, 0, 6, 0, 0, 0, 0, 6, 0, 0, 4, 6, 3, 0,
#         1, 2, 2, 0, 3, 6, 6, 0, 5, 0, 3, 5, 3, 2, 6, 4, 0, 6, 6, 3, 0, 6, 6, 6,
#         6, 2, 6, 0, 2, 0, 2, 0, 6, 5, 6, 6, 0, 6, 0, 1, 0, 4, 0, 1, 0, 6, 6, 6,
#         6, 4, 0, 0, 0, 6, 6, 4, 1, 0, 0, 2, 2, 1, 2, 4, 6, 1, 6, 2, 2, 0, 6, 6,
#         3, 2, 3, 0, 6, 0, 0, 6, 6, 0, 0, 6, 6, 6, 0, 1, 6, 6, 1, 2, 5, 0, 3, 2,
#         0, 1, 4, 1, 4, 6, 1, 4, 6, 0, 1, 2, 0, 2, 2, 2, 2, 0, 2, 6, 6, 0, 0, 2,
#         1, 0, 6, 4, 0, 0, 2, 6, 1, 0, 0, 1, 1, 0, 0, 6, 0, 0, 6, 6, 4, 4, 2, 2,
#         0, 1, 6, 6, 6, 0, 2, 1, 0, 3, 4, 0, 0, 1, 6, 4])
# Batch Index: 8
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.2550, -0.2713, -0.2694,  ..., -0.0381,  0.0124,  0.3898],
#         [-0.6765, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6651, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.5946, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6805, -0.2714, -0.2680,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([1, 1, 0, 4, 1, 6, 2, 2, 2, 1, 0, 4, 6, 1, 0, 6, 1, 1, 0, 6, 6, 1, 0, 6,
#         0, 6, 0, 0, 6, 6, 4, 5, 6, 0, 0, 0, 0, 0, 4, 3, 4, 0, 0, 1, 6, 6, 0, 2,
#         2, 0, 6, 2, 0, 6, 3, 0, 6, 1, 4, 1, 0, 6, 6, 0, 0, 6, 4, 0, 0, 0, 1, 0,
#         2, 6, 6, 1, 6, 0, 1, 6, 6, 0, 2, 6, 0, 0, 0, 0, 6, 6, 0, 0, 6, 0, 1, 0,
#         0, 4, 2, 0, 6, 4, 6, 0, 5, 3, 3, 4, 0, 2, 0, 1, 2, 5, 2, 0, 6, 4, 4, 2,
#         6, 0, 3, 4, 0, 1, 6, 5, 1, 6, 6, 2, 6, 0, 2, 6, 0, 2, 2, 6, 6, 6, 5, 3,
#         2, 0, 2, 0, 0, 0, 0, 0, 6, 2, 6, 1, 0, 6, 1, 6, 6, 2, 4, 4, 2, 6, 0, 1,
#         1, 6, 6, 4, 3, 6, 2, 0, 0, 0, 0, 6, 0, 0, 0, 5, 0, 0, 2, 4, 0, 0, 0, 2,
#         0, 6, 6, 5, 0, 6, 0, 6, 0, 0, 0, 0, 0, 3, 3, 6, 2, 4, 2, 4, 6, 6, 5, 0,
#         0, 5, 2, 1, 4, 1, 0, 0, 0, 6, 1, 3, 6, 0, 5, 0, 2, 1, 0, 6, 6, 2, 1, 4,
#         2, 6, 0, 0, 0, 6, 6, 0, 5, 0, 6, 5, 5, 0, 2, 2])
# Batch Index: 9
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6626, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6771, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0200,  4.2048,  4.0463,  ...,  0.4954,  0.4509, -0.1627],
#         ...,
#         [ 0.3607, -0.2713, -0.2680,  ...,  0.4942,  0.4497, -0.1627],
#         [-0.6712, -0.2101, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2654, -0.2713, -0.2694,  ...,  0.1596,  0.4249,  1.9507]])
# Targets:
# tensor([2, 4, 6, 6, 6, 0, 6, 6, 4, 3, 0, 4, 0, 6, 1, 0, 6, 2, 6, 0, 4, 0, 0, 2,
#         6, 6, 4, 1, 1, 6, 4, 6, 0, 4, 6, 2, 4, 2, 1, 0, 0, 0, 6, 6, 0, 0, 1, 6,
#         5, 6, 6, 6, 0, 1, 0, 1, 0, 6, 4, 0, 4, 2, 1, 6, 6, 6, 0, 0, 4, 3, 2, 6,
#         6, 1, 2, 0, 4, 2, 6, 0, 0, 5, 6, 6, 0, 2, 6, 0, 6, 4, 0, 6, 2, 4, 0, 5,
#         6, 2, 6, 6, 2, 0, 4, 6, 0, 4, 4, 6, 1, 5, 0, 0, 0, 2, 6, 0, 0, 1, 0, 1,
#         6, 6, 0, 2, 2, 5, 6, 0, 2, 6, 0, 0, 4, 0, 6, 0, 6, 1, 6, 6, 0, 0, 6, 6,
#         1, 6, 6, 2, 6, 3, 2, 0, 0, 0, 6, 1, 2, 5, 6, 0, 6, 1, 6, 0, 2, 6, 5, 1,
#         0, 3, 1, 4, 2, 4, 0, 0, 0, 6, 0, 6, 1, 4, 5, 5, 6, 0, 2, 0, 2, 5, 4, 6,
#         6, 2, 0, 5, 6, 0, 6, 6, 0, 6, 0, 4, 4, 0, 2, 4, 2, 1, 4, 0, 0, 6, 0, 0,
#         0, 4, 4, 0, 6, 4, 0, 2, 0, 0, 6, 0, 4, 2, 4, 0, 6, 1, 2, 3, 2, 6, 5, 2,
#         4, 2, 3, 0, 6, 5, 3, 3, 0, 0, 6, 2, 2, 3, 1, 0])
# Batch Index: 10
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6664, -0.2714, -0.1806,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3619, -0.2713, -0.2694,  ...,  0.0431,  0.0310, -0.0482],
#         [ 0.3612, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6771, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2005, -0.2713, -0.2694,  ..., -0.0045, -0.0173, -0.0237],
#         [-0.6683, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([0, 0, 5, 0, 2, 2, 2, 4, 6, 3, 1, 5, 1, 4, 5, 2, 6, 6, 0, 2, 0, 2, 2, 2,
#         2, 0, 2, 3, 2, 0, 6, 0, 2, 6, 0, 5, 6, 5, 4, 0, 4, 2, 6, 3, 0, 1, 0, 1,
#         0, 1, 4, 4, 2, 0, 4, 4, 4, 1, 0, 6, 6, 0, 0, 0, 6, 4, 1, 1, 0, 6, 2, 6,
#         0, 6, 2, 1, 6, 5, 6, 6, 1, 6, 6, 6, 6, 5, 2, 4, 0, 2, 2, 0, 5, 5, 0, 0,
#         0, 0, 4, 2, 3, 6, 2, 0, 2, 0, 0, 6, 6, 5, 6, 6, 4, 0, 0, 1, 4, 6, 5, 1,
#         6, 4, 1, 0, 2, 6, 4, 2, 2, 4, 0, 1, 3, 6, 6, 0, 6, 1, 0, 0, 2, 6, 2, 2,
#         3, 1, 6, 0, 2, 6, 4, 0, 0, 2, 6, 6, 1, 6, 6, 0, 6, 6, 5, 0, 0, 0, 6, 6,
#         0, 6, 2, 0, 0, 0, 4, 0, 6, 0, 5, 1, 2, 0, 2, 6, 2, 2, 6, 0, 2, 1, 0, 1,
#         5, 4, 0, 2, 1, 0, 0, 0, 2, 1, 6, 0, 1, 1, 2, 6, 1, 2, 5, 6, 0, 2, 6, 3,
#         2, 0, 6, 0, 1, 6, 6, 6, 3, 6, 6, 3, 6, 2, 5, 4, 6, 5, 4, 4, 0, 0, 5, 6,
#         0, 0, 1, 4, 3, 1, 2, 2, 4, 5, 4, 5, 6, 4, 5, 2])
# Batch Index: 11
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3049, -0.2713, -0.2694,  ...,  0.1455,  0.2558,  0.8542],
#         [-0.6657, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0218, -0.2713, -0.2693,  ...,  0.4953,  0.4508, -0.1627],
#         ...,
#         [ 0.3620, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2601,  5.7617,  5.5477,  ...,  0.7552,  0.7050, -0.1627],
#         [-0.0923, -0.2713, -0.2694,  ...,  0.3536,  0.3135, -0.1627]])
# Targets:
# tensor([0, 0, 0, 0, 0, 6, 2, 2, 6, 6, 4, 5, 3, 0, 2, 0, 0, 2, 5, 4, 1, 6, 0, 0,
#         5, 1, 6, 0, 5, 6, 1, 0, 5, 0, 6, 2, 0, 0, 0, 2, 4, 6, 2, 2, 5, 4, 6, 6,
#         3, 0, 0, 1, 5, 4, 4, 0, 4, 4, 6, 6, 4, 5, 1, 4, 2, 0, 4, 3, 6, 0, 0, 0,
#         6, 0, 1, 5, 1, 5, 4, 6, 0, 4, 4, 0, 0, 0, 0, 1, 6, 1, 6, 1, 3, 0, 0, 6,
#         4, 1, 2, 6, 4, 5, 1, 0, 3, 6, 2, 6, 6, 0, 4, 6, 0, 0, 0, 0, 1, 2, 5, 3,
#         5, 0, 0, 6, 1, 0, 0, 4, 6, 6, 2, 0, 6, 1, 5, 6, 6, 0, 1, 1, 0, 2, 0, 0,
#         2, 0, 6, 6, 5, 5, 4, 5, 0, 0, 0, 0, 1, 0, 0, 3, 6, 0, 0, 0, 6, 6, 0, 6,
#         6, 6, 4, 4, 1, 0, 2, 0, 0, 2, 6, 2, 6, 0, 0, 6, 0, 0, 4, 4, 6, 4, 2, 0,
#         3, 2, 0, 2, 4, 6, 2, 2, 3, 1, 0, 2, 6, 1, 4, 0, 4, 2, 2, 3, 6, 6, 0, 0,
#         2, 2, 2, 6, 4, 1, 6, 5, 4, 6, 1, 4, 6, 0, 1, 0, 6, 2, 1, 0, 5, 6, 6, 0,
#         1, 6, 0, 6, 6, 2, 5, 0, 1, 2, 2, 6, 6, 6, 4, 0])
# Batch Index: 12
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.2490, -0.2713, -0.2694,  ...,  0.0390,  0.2532,  0.8952],
#         [ 0.3618, -0.2701, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6768, -0.2711, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3610, -0.2645, -0.2670,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.1378, -0.2094, -0.2693,  ...,  0.4897,  0.4454, -0.1627]])
# Targets:
# tensor([0, 6, 4, 0, 6, 0, 0, 2, 6, 6, 4, 0, 0, 3, 6, 1, 0, 4, 6, 6, 6, 2, 1, 1,
#         6, 1, 0, 1, 2, 3, 0, 2, 6, 2, 0, 1, 1, 6, 6, 1, 0, 0, 0, 3, 0, 1, 0, 0,
#         0, 6, 6, 6, 1, 0, 6, 6, 6, 6, 4, 6, 6, 2, 0, 0, 0, 0, 6, 0, 6, 1, 2, 2,
#         4, 2, 6, 2, 5, 0, 2, 6, 2, 0, 4, 1, 2, 0, 5, 0, 1, 0, 6, 1, 2, 2, 6, 1,
#         0, 5, 2, 0, 1, 4, 0, 4, 6, 2, 4, 6, 2, 6, 4, 0, 0, 5, 4, 0, 0, 0, 4, 2,
#         0, 0, 6, 2, 0, 5, 0, 5, 0, 1, 6, 2, 1, 6, 4, 0, 2, 0, 1, 0, 5, 6, 4, 2,
#         0, 1, 0, 6, 2, 6, 0, 1, 1, 1, 6, 2, 4, 6, 6, 3, 0, 0, 0, 0, 6, 1, 6, 1,
#         3, 0, 1, 0, 0, 2, 6, 0, 0, 5, 0, 6, 6, 0, 5, 6, 6, 2, 1, 6, 2, 2, 6, 6,
#         2, 5, 4, 6, 2, 0, 0, 6, 0, 3, 0, 0, 4, 2, 2, 0, 0, 2, 3, 6, 0, 4, 1, 0,
#         6, 5, 6, 6, 1, 6, 0, 0, 1, 4, 5, 6, 2, 5, 6, 6, 2, 5, 2, 1, 6, 2, 4, 5,
#         0, 0, 1, 0, 6, 0, 4, 2, 6, 6, 4, 0, 2, 0, 6, 1])
# Batch Index: 13
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.3785, -0.2713, -0.2694,  ...,  0.0279, -0.0023, -0.1627],
#         [-0.6569, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3619, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3612, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6718, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([0, 5, 6, 6, 4, 6, 0, 0, 4, 2, 1, 0, 0, 0, 2, 6, 0, 0, 0, 6, 0, 2, 4, 0,
#         3, 2, 2, 0, 1, 6, 2, 2, 6, 6, 6, 0, 2, 0, 4, 0, 6, 6, 6, 6, 0, 2, 0, 0,
#         0, 1, 1, 0, 6, 0, 0, 4, 3, 2, 0, 4, 6, 0, 5, 1, 6, 6, 0, 6, 4, 0, 2, 4,
#         3, 4, 2, 3, 2, 0, 2, 3, 4, 4, 2, 6, 0, 4, 6, 6, 6, 6, 6, 4, 0, 5, 6, 2,
#         0, 1, 2, 6, 0, 0, 6, 1, 1, 0, 4, 6, 0, 0, 6, 6, 0, 6, 3, 1, 6, 0, 2, 0,
#         5, 0, 0, 0, 3, 6, 6, 0, 6, 0, 4, 0, 6, 5, 6, 0, 5, 1, 6, 5, 2, 0, 2, 0,
#         2, 6, 6, 6, 3, 0, 2, 6, 6, 6, 6, 2, 0, 4, 0, 3, 1, 6, 6, 2, 2, 0, 2, 0,
#         6, 6, 0, 2, 4, 2, 2, 1, 6, 4, 5, 6, 1, 6, 1, 4, 0, 2, 0, 3, 0, 6, 4, 2,
#         0, 0, 1, 4, 1, 6, 4, 6, 0, 1, 0, 1, 0, 6, 1, 6, 4, 6, 6, 0, 2, 6, 2, 0,
#         6, 3, 2, 6, 1, 5, 4, 4, 0, 1, 4, 2, 6, 2, 4, 6, 0, 5, 2, 2, 0, 6, 0, 6,
#         6, 1, 6, 2, 6, 3, 0, 1, 4, 2, 6, 0, 4, 1, 6, 4])
# Batch Index: 14
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.3555, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.0627, -0.2714, -0.2694,  ...,  0.3426,  0.3028, -0.1627],
#         ...,
#         [ 0.0198,  4.2037,  4.0454,  ...,  0.4954,  0.4508, -0.1627],
#         [-0.3995, -0.2714, -0.2694,  ...,  0.0416,  0.0110, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([2, 4, 0, 6, 0, 4, 6, 5, 6, 6, 2, 1, 1, 2, 5, 0, 4, 6, 2, 2, 0, 6, 0, 0,
#         1, 4, 0, 1, 0, 1, 4, 4, 0, 4, 6, 0, 2, 6, 2, 6, 6, 6, 6, 4, 2, 0, 6, 5,
#         0, 4, 4, 1, 6, 4, 1, 2, 6, 6, 0, 2, 3, 6, 0, 0, 0, 6, 0, 4, 5, 2, 0, 1,
#         2, 1, 0, 1, 4, 6, 2, 6, 2, 6, 6, 1, 2, 4, 6, 6, 5, 1, 0, 5, 2, 4, 0, 0,
#         6, 5, 6, 6, 1, 0, 0, 2, 0, 0, 6, 6, 4, 0, 4, 6, 1, 0, 6, 0, 4, 6, 2, 3,
#         6, 4, 6, 6, 0, 5, 0, 0, 6, 1, 2, 4, 0, 0, 0, 0, 6, 0, 6, 0, 6, 6, 6, 2,
#         2, 3, 2, 1, 6, 6, 1, 1, 0, 1, 1, 6, 0, 4, 2, 1, 2, 1, 6, 0, 0, 0, 2, 1,
#         6, 2, 5, 6, 3, 0, 0, 1, 0, 6, 0, 4, 0, 0, 6, 4, 6, 0, 6, 6, 1, 4, 6, 6,
#         0, 0, 6, 6, 6, 0, 6, 0, 4, 2, 6, 1, 4, 0, 6, 6, 2, 6, 1, 5, 6, 6, 0, 0,
#         0, 2, 6, 6, 2, 0, 0, 6, 0, 0, 6, 6, 1, 1, 6, 6, 6, 2, 6, 6, 6, 6, 0, 4,
#         0, 2, 0, 5, 0, 5, 6, 2, 0, 1, 2, 2, 5, 6, 0, 4])
# Batch Index: 15
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6615, -0.1481, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0200,  4.2045,  4.0461,  ...,  0.4954,  0.4509, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0198,  4.2036,  4.0455,  ...,  0.4954,  0.4508, -0.1627],
#         [ 0.3618, -0.2644, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([0, 6, 2, 6, 4, 2, 1, 6, 0, 1, 6, 2, 0, 6, 6, 2, 0, 6, 0, 4, 2, 6, 6, 4,
#         6, 4, 6, 4, 0, 6, 6, 0, 0, 1, 2, 5, 0, 6, 2, 2, 2, 0, 0, 4, 6, 6, 6, 0,
#         5, 1, 6, 5, 4, 2, 0, 6, 0, 4, 3, 0, 0, 1, 0, 0, 0, 4, 6, 6, 2, 1, 0, 6,
#         0, 6, 0, 0, 3, 2, 5, 6, 0, 6, 6, 1, 2, 2, 1, 5, 6, 6, 6, 1, 0, 2, 2, 0,
#         1, 6, 6, 1, 2, 4, 0, 4, 2, 2, 0, 4, 0, 4, 6, 6, 2, 0, 6, 3, 0, 0, 5, 6,
#         3, 0, 0, 0, 4, 0, 6, 1, 0, 6, 0, 4, 2, 6, 1, 1, 3, 5, 0, 6, 0, 2, 2, 6,
#         6, 5, 0, 6, 6, 0, 4, 6, 0, 0, 5, 0, 0, 1, 0, 0, 0, 5, 5, 1, 6, 0, 5, 1,
#         5, 1, 4, 6, 6, 6, 6, 6, 2, 0, 2, 0, 2, 0, 0, 0, 1, 1, 6, 4, 0, 6, 0, 2,
#         4, 5, 5, 2, 0, 0, 2, 6, 4, 3, 6, 1, 0, 2, 0, 1, 1, 5, 4, 0, 6, 0, 6, 5,
#         5, 6, 4, 6, 4, 0, 6, 3, 6, 4, 6, 0, 0, 0, 0, 6, 2, 2, 1, 1, 4, 4, 0, 2,
#         5, 2, 1, 2, 0, 1, 6, 0, 0, 6, 6, 0, 0, 4, 6, 6])
# Batch Index: 16
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6664, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.5224, -0.2710, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.2453, -0.1767, -0.1781,  ...,  0.0955,  0.0633, -0.1627],
#         ...,
#         [-0.6555, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3620, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.1495, -0.2714, -0.2694,  ..., -0.0944,  0.0798,  0.4000]])
# Targets:
# tensor([0, 3, 2, 0, 1, 6, 0, 6, 6, 6, 5, 4, 2, 0, 6, 6, 4, 1, 6, 5, 4, 1, 1, 6,
#         6, 1, 6, 0, 0, 0, 0, 2, 4, 2, 5, 6, 0, 2, 0, 6, 0, 0, 1, 1, 2, 2, 6, 4,
#         0, 6, 4, 6, 6, 6, 2, 6, 4, 2, 0, 6, 0, 6, 2, 0, 2, 4, 0, 0, 1, 4, 4, 6,
#         1, 6, 1, 2, 6, 6, 3, 1, 0, 6, 0, 0, 6, 0, 4, 6, 2, 2, 0, 6, 3, 6, 6, 0,
#         0, 6, 0, 6, 3, 6, 4, 6, 0, 6, 1, 0, 6, 2, 4, 6, 5, 4, 4, 6, 1, 2, 6, 6,
#         6, 2, 0, 0, 4, 6, 2, 3, 1, 6, 2, 3, 1, 1, 0, 1, 2, 6, 6, 6, 6, 0, 1, 6,
#         6, 0, 6, 3, 2, 6, 1, 6, 1, 0, 1, 3, 2, 5, 6, 0, 2, 0, 6, 4, 4, 3, 6, 6,
#         2, 1, 4, 4, 6, 6, 6, 0, 0, 0, 0, 6, 6, 0, 2, 4, 5, 4, 6, 2, 2, 6, 4, 6,
#         4, 6, 0, 1, 3, 2, 4, 6, 3, 6, 2, 6, 0, 2, 0, 0, 4, 0, 1, 6, 0, 4, 0, 1,
#         0, 6, 0, 3, 6, 4, 5, 0, 6, 6, 6, 4, 6, 6, 2, 0, 6, 4, 3, 4, 6, 4, 4, 4,
#         1, 6, 0, 0, 0, 2, 6, 6, 6, 0, 0, 0, 0, 0, 6, 0])
# Batch Index: 17
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3618, -0.2714, -0.2692,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2241,  1.0672,  0.9990,  ...,  0.0739,  0.2352,  0.6710],
#         [-0.6753, -0.2457, -0.2442,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.3590, -0.2714, -0.2690,  ..., -0.1513, -0.1760, -0.1627],
#         [-0.1149, -0.2713, -0.2694,  ..., -0.1066, -0.1313, -0.1563],
#         [ 0.0846,  1.9625,  1.8809,  ...,  0.1614,  0.1629,  0.0898]])
# Targets:
# tensor([2, 2, 1, 6, 0, 0, 3, 0, 4, 6, 6, 1, 1, 3, 0, 2, 1, 6, 4, 2, 6, 6, 0, 6,
#         2, 0, 6, 1, 0, 2, 4, 1, 2, 1, 0, 6, 4, 2, 0, 2, 6, 6, 2, 0, 1, 2, 0, 4,
#         6, 6, 6, 2, 0, 2, 6, 6, 6, 2, 2, 1, 0, 4, 0, 5, 6, 6, 4, 0, 2, 2, 0, 0,
#         0, 1, 0, 2, 0, 6, 5, 4, 0, 0, 0, 0, 6, 1, 0, 2, 4, 2, 1, 0, 0, 4, 5, 6,
#         6, 1, 4, 6, 6, 0, 0, 0, 1, 4, 1, 0, 5, 6, 6, 0, 1, 0, 2, 0, 2, 6, 6, 2,
#         6, 0, 0, 2, 0, 6, 6, 2, 6, 2, 6, 6, 0, 0, 2, 0, 1, 1, 6, 1, 0, 2, 1, 5,
#         2, 5, 0, 4, 4, 6, 4, 6, 0, 0, 6, 3, 6, 5, 1, 2, 6, 4, 6, 0, 6, 0, 6, 6,
#         0, 6, 4, 1, 6, 0, 4, 6, 2, 2, 6, 6, 6, 6, 0, 6, 0, 5, 3, 5, 1, 4, 0, 2,
#         2, 6, 2, 1, 5, 0, 6, 1, 0, 0, 4, 2, 6, 4, 2, 0, 6, 4, 1, 0, 3, 6, 6, 6,
#         6, 5, 3, 6, 0, 1, 0, 1, 6, 6, 1, 1, 2, 1, 0, 6, 6, 1, 6, 1, 2, 0, 5, 2,
#         3, 0, 6, 6, 1, 0, 0, 4, 0, 4, 1, 1, 4, 2, 0, 4])
# Batch Index: 18
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3620, -0.2701, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0221, -0.2713, -0.2694,  ...,  0.4850,  0.4408, -0.1627],
#         [-0.6765, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6678, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2186, -0.2712, -0.2694,  ...,  0.1675,  0.4510,  2.0813],
#         [ 0.3618, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([6, 0, 4, 6, 3, 4, 1, 2, 3, 1, 1, 3, 4, 3, 6, 6, 0, 0, 0, 3, 2, 6, 6, 2,
#         2, 6, 2, 0, 6, 1, 2, 1, 6, 3, 6, 1, 5, 2, 0, 1, 2, 4, 6, 6, 6, 0, 2, 1,
#         2, 0, 3, 0, 4, 0, 2, 6, 4, 0, 4, 1, 6, 0, 0, 6, 1, 6, 6, 6, 0, 6, 2, 0,
#         2, 0, 0, 1, 4, 6, 4, 2, 6, 0, 0, 2, 4, 0, 6, 3, 6, 6, 0, 6, 6, 6, 3, 3,
#         6, 5, 2, 0, 4, 0, 0, 4, 1, 6, 0, 2, 6, 6, 3, 6, 0, 6, 6, 2, 2, 1, 6, 6,
#         1, 2, 2, 0, 2, 3, 2, 4, 0, 6, 2, 2, 3, 1, 0, 6, 0, 0, 4, 6, 0, 2, 0, 0,
#         2, 1, 4, 0, 6, 1, 6, 0, 6, 6, 6, 0, 3, 1, 5, 0, 0, 0, 6, 5, 0, 0, 0, 1,
#         5, 0, 6, 2, 0, 0, 6, 5, 1, 0, 1, 1, 0, 0, 4, 2, 2, 6, 1, 2, 0, 6, 1, 0,
#         2, 0, 6, 0, 6, 2, 0, 3, 6, 6, 4, 6, 0, 4, 2, 2, 3, 3, 1, 2, 4, 6, 1, 4,
#         2, 1, 4, 6, 2, 4, 6, 6, 6, 6, 4, 1, 4, 4, 6, 6, 0, 1, 2, 4, 0, 1, 3, 6,
#         0, 5, 6, 0, 6, 0, 6, 0, 6, 4, 0, 2, 0, 4, 0, 6])
# Batch Index: 19
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3612, -0.2712, -0.2694,  ...,  0.0067, -0.0228, -0.1627],
#         [ 0.3235,  0.1565,  0.1429,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6735, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6566, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3611, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([2, 6, 0, 1, 1, 1, 0, 6, 2, 0, 0, 6, 1, 0, 2, 6, 0, 6, 4, 3, 6, 5, 6, 2,
#         6, 2, 6, 2, 3, 4, 6, 2, 6, 6, 0, 4, 4, 2, 4, 2, 0, 6, 6, 0, 6, 6, 5, 2,
#         0, 0, 1, 6, 6, 3, 6, 4, 4, 0, 2, 0, 6, 2, 0, 6, 0, 4, 2, 0, 6, 1, 0, 4,
#         4, 2, 6, 4, 0, 6, 2, 6, 2, 2, 6, 0, 6, 0, 0, 1, 2, 4, 4, 0, 0, 2, 6, 6,
#         2, 0, 6, 4, 0, 2, 1, 4, 0, 6, 5, 6, 6, 0, 0, 6, 2, 6, 6, 0, 2, 0, 6, 0,
#         6, 2, 6, 6, 6, 0, 0, 1, 2, 0, 6, 2, 2, 6, 6, 2, 2, 4, 6, 6, 6, 6, 6, 2,
#         4, 6, 6, 6, 6, 0, 0, 6, 0, 6, 0, 4, 0, 1, 4, 6, 0, 2, 0, 6, 6, 6, 0, 2,
#         6, 0, 3, 6, 2, 6, 4, 0, 0, 6, 6, 3, 4, 2, 0, 6, 2, 6, 0, 3, 2, 1, 4, 2,
#         2, 0, 1, 6, 4, 0, 6, 0, 2, 4, 2, 0, 0, 0, 4, 2, 6, 4, 0, 6, 1, 6, 5, 0,
#         6, 6, 4, 0, 4, 3, 6, 4, 1, 1, 0, 0, 0, 2, 1, 3, 4, 2, 1, 4, 4, 6, 0, 0,
#         0, 0, 4, 0, 0, 6, 1, 0, 6, 1, 2, 3, 4, 0, 5, 4])
# Batch Index: 20
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.1881, -0.2713, -0.2694,  ..., -0.0107, -0.0185, -0.0133],
#         [ 0.3234,  0.1564,  0.1426,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3615, -0.2713, -0.2694,  ...,  0.0868,  0.1405,  0.2262],
#         ...,
#         [-0.6580, -0.1254, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3231,  0.1564,  0.1422,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3222,  0.1564,  0.1430,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([5, 6, 1, 3, 1, 1, 2, 1, 2, 6, 6, 6, 2, 6, 4, 1, 1, 0, 0, 1, 0, 0, 2, 6,
#         3, 2, 0, 2, 1, 0, 0, 1, 2, 2, 6, 2, 1, 6, 0, 3, 0, 3, 5, 6, 0, 4, 0, 2,
#         0, 6, 0, 6, 5, 6, 0, 2, 0, 2, 4, 0, 5, 2, 4, 2, 6, 0, 1, 4, 6, 4, 0, 1,
#         0, 0, 0, 0, 4, 3, 2, 6, 0, 2, 2, 6, 6, 3, 0, 0, 6, 0, 6, 0, 0, 5, 6, 0,
#         0, 0, 2, 5, 0, 2, 2, 2, 6, 0, 6, 5, 2, 2, 5, 6, 6, 5, 2, 1, 5, 5, 0, 0,
#         3, 3, 1, 2, 2, 0, 6, 0, 0, 6, 6, 2, 2, 6, 2, 6, 0, 6, 0, 5, 5, 0, 1, 0,
#         1, 3, 4, 6, 0, 2, 0, 5, 0, 0, 2, 2, 2, 2, 6, 1, 4, 2, 2, 4, 6, 0, 6, 6,
#         6, 0, 0, 6, 6, 0, 0, 6, 6, 6, 6, 2, 5, 6, 6, 4, 0, 2, 6, 0, 6, 2, 6, 3,
#         6, 6, 1, 6, 4, 6, 0, 2, 0, 6, 6, 2, 0, 0, 6, 0, 2, 0, 6, 0, 4, 6, 0, 2,
#         1, 6, 6, 2, 0, 0, 0, 6, 6, 6, 2, 6, 1, 6, 1, 0, 1, 6, 5, 0, 6, 6, 1, 0,
#         0, 0, 0, 6, 6, 6, 0, 4, 1, 0, 6, 3, 6, 2, 6, 6])
# Batch Index: 21
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.0950, -0.2713, -0.2694,  ..., -0.0849, -0.0601,  0.0602],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3378, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.2135, -0.2713, -0.2694,  ...,  0.1030,  0.3093,  1.5229],
#         [ 0.3466, -0.2713, -0.2694,  ..., -0.1494, -0.1280, -0.0300],
#         [ 0.3620, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([0, 5, 2, 1, 6, 0, 0, 3, 6, 5, 6, 6, 6, 1, 0, 2, 6, 6, 0, 2, 1, 1, 0, 1,
#         6, 2, 1, 4, 0, 4, 2, 0, 6, 6, 6, 0, 2, 6, 3, 2, 6, 3, 2, 1, 1, 1, 2, 1,
#         2, 6, 1, 6, 6, 4, 4, 6, 0, 2, 2, 0, 0, 6, 5, 3, 5, 6, 6, 1, 6, 4, 1, 6,
#         6, 2, 0, 6, 2, 4, 4, 1, 2, 0, 6, 5, 0, 0, 1, 6, 2, 2, 2, 6, 3, 0, 6, 1,
#         6, 3, 4, 6, 6, 2, 0, 2, 6, 5, 6, 1, 0, 6, 0, 4, 0, 4, 3, 0, 2, 0, 6, 1,
#         0, 2, 4, 1, 1, 6, 6, 4, 0, 1, 6, 2, 5, 1, 6, 6, 4, 2, 2, 2, 0, 1, 5, 0,
#         6, 6, 5, 0, 0, 0, 0, 3, 2, 6, 4, 1, 4, 0, 1, 1, 6, 4, 0, 4, 6, 3, 4, 0,
#         6, 2, 4, 2, 6, 1, 1, 4, 6, 2, 6, 0, 6, 2, 0, 4, 0, 6, 4, 0, 2, 0, 0, 6,
#         2, 6, 5, 0, 1, 1, 6, 6, 6, 3, 3, 0, 6, 0, 0, 1, 6, 0, 6, 6, 0, 2, 6, 2,
#         2, 0, 4, 5, 6, 3, 6, 4, 6, 0, 1, 0, 2, 1, 4, 6, 6, 4, 5, 0, 4, 2, 4, 6,
#         2, 6, 0, 1, 0, 1, 2, 6, 4, 2, 0, 0, 6, 2, 1, 6])
# Batch Index: 22
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.5004, -0.2713, -0.2678,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3545, -0.2711, -0.2683,  ...,  0.2104,  0.4839,  2.0199],
#         [ 0.3363, -0.2713, -0.2694,  ..., -0.0450,  0.0280,  0.2695],
#         ...,
#         [ 0.3481, -0.2713, -0.2694,  ...,  0.7329,  0.6782, -0.1627],
#         [-0.4715, -0.2713, -0.2694,  ..., -0.0356, -0.0638, -0.1627],
#         [ 0.3619, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([3, 2, 1, 0, 6, 4, 0, 4, 2, 3, 6, 0, 0, 0, 2, 0, 5, 2, 6, 2, 0, 0, 6, 0,
#         6, 1, 0, 1, 4, 2, 4, 2, 2, 6, 0, 2, 0, 4, 2, 4, 3, 0, 6, 2, 6, 1, 0, 3,
#         6, 2, 3, 0, 2, 6, 6, 0, 3, 6, 5, 2, 6, 2, 3, 2, 2, 3, 0, 6, 0, 2, 6, 6,
#         5, 0, 0, 3, 1, 6, 1, 0, 0, 0, 6, 0, 4, 1, 6, 6, 0, 4, 2, 6, 1, 6, 0, 4,
#         5, 4, 2, 6, 6, 6, 6, 5, 1, 6, 6, 3, 1, 6, 6, 0, 0, 4, 1, 1, 6, 0, 6, 0,
#         2, 3, 4, 2, 1, 1, 2, 4, 6, 2, 2, 1, 0, 6, 6, 6, 0, 0, 1, 0, 0, 2, 6, 0,
#         0, 1, 2, 5, 6, 0, 6, 5, 5, 6, 6, 4, 2, 6, 6, 6, 2, 6, 6, 0, 0, 6, 6, 6,
#         0, 5, 6, 0, 0, 3, 0, 0, 2, 1, 6, 1, 0, 2, 4, 3, 2, 1, 0, 6, 1, 2, 6, 6,
#         6, 4, 6, 4, 1, 0, 6, 2, 4, 0, 2, 0, 5, 0, 4, 5, 0, 3, 0, 4, 0, 1, 2, 2,
#         0, 2, 0, 1, 6, 0, 5, 6, 2, 6, 6, 0, 4, 0, 0, 4, 6, 0, 1, 0, 0, 1, 2, 1,
#         5, 6, 6, 0, 6, 5, 0, 2, 2, 0, 2, 6, 1, 1, 0, 6])
# Batch Index: 23
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3609, -0.2713, -0.2694,  ...,  0.0193,  0.0748,  0.1454],
#         [-0.6767, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2127, -0.2713, -0.2694,  ...,  0.6216,  0.5725, -0.1627],
#         ...,
#         [-0.6648, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.4513, -0.2023, -0.2391,  ..., -0.0822, -0.1090, -0.1627],
#         [-0.6667, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([0, 1, 1, 0, 1, 4, 0, 4, 0, 0, 6, 0, 6, 4, 0, 0, 6, 2, 5, 6, 0, 4, 1, 0,
#         2, 0, 0, 4, 0, 6, 3, 4, 6, 6, 1, 3, 6, 4, 4, 0, 0, 1, 6, 6, 2, 6, 0, 0,
#         6, 4, 6, 1, 6, 6, 6, 2, 2, 2, 6, 1, 6, 6, 6, 2, 0, 6, 0, 0, 0, 2, 0, 4,
#         1, 0, 0, 2, 2, 6, 6, 4, 0, 6, 1, 6, 6, 2, 2, 6, 0, 6, 2, 2, 6, 0, 1, 6,
#         1, 5, 4, 0, 0, 2, 2, 2, 3, 1, 0, 1, 6, 2, 0, 6, 0, 0, 2, 0, 0, 4, 6, 4,
#         3, 4, 0, 1, 2, 4, 0, 2, 6, 2, 6, 5, 2, 6, 6, 2, 0, 0, 5, 6, 0, 5, 1, 0,
#         4, 5, 0, 4, 3, 6, 6, 6, 1, 0, 0, 0, 0, 5, 3, 6, 0, 1, 0, 2, 6, 0, 2, 0,
#         6, 0, 1, 6, 1, 0, 1, 2, 0, 1, 6, 2, 6, 0, 1, 0, 6, 6, 1, 5, 4, 0, 0, 0,
#         3, 4, 0, 6, 0, 1, 0, 4, 0, 1, 1, 6, 6, 6, 2, 0, 1, 4, 6, 0, 0, 6, 4, 4,
#         6, 1, 2, 1, 0, 4, 0, 0, 0, 1, 6, 0, 0, 6, 4, 0, 3, 0, 6, 1, 5, 0, 4, 0,
#         0, 0, 6, 2, 6, 6, 0, 4, 0, 1, 6, 2, 2, 4, 0, 0])
# Batch Index: 24
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6674, -0.2682, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6606, -0.1423, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.1974, -0.2714, -0.2694,  ..., -0.0563,  0.2328,  0.8912],
#         ...,
#         [-0.0302,  3.7950,  3.6513,  ...,  0.4127,  0.3707, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3600, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([0, 0, 0, 0, 4, 6, 0, 2, 6, 0, 0, 6, 2, 0, 0, 3, 0, 6, 3, 2, 0, 4, 2, 5,
#         4, 6, 6, 0, 2, 0, 6, 6, 6, 6, 6, 0, 6, 1, 6, 6, 1, 1, 0, 2, 2, 3, 6, 0,
#         6, 0, 0, 0, 6, 6, 6, 6, 0, 5, 3, 0, 0, 6, 6, 1, 4, 1, 6, 5, 5, 1, 0, 5,
#         6, 0, 6, 0, 1, 5, 0, 6, 0, 0, 4, 2, 0, 6, 4, 2, 2, 4, 4, 2, 1, 2, 0, 5,
#         1, 2, 2, 5, 2, 0, 4, 6, 6, 5, 0, 3, 0, 3, 6, 3, 2, 4, 2, 2, 0, 0, 6, 4,
#         2, 1, 2, 6, 1, 2, 2, 2, 6, 0, 6, 1, 2, 4, 0, 0, 0, 1, 6, 3, 6, 0, 6, 6,
#         4, 0, 6, 1, 2, 6, 2, 1, 6, 0, 3, 2, 2, 6, 6, 0, 0, 6, 2, 5, 6, 6, 4, 6,
#         5, 0, 0, 6, 1, 0, 3, 0, 6, 6, 4, 4, 2, 0, 0, 0, 5, 1, 2, 6, 5, 5, 3, 2,
#         2, 6, 2, 2, 0, 1, 3, 0, 0, 6, 6, 3, 1, 0, 1, 0, 0, 6, 0, 1, 2, 5, 2, 2,
#         0, 4, 6, 0, 6, 0, 0, 0, 6, 0, 3, 2, 6, 6, 0, 3, 6, 0, 1, 4, 0, 2, 0, 5,
#         0, 0, 0, 0, 0, 0, 0, 5, 0, 0, 0, 2, 5, 2, 4, 5])
# Batch Index: 25
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3619, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2193, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0199,  4.2043,  4.0461,  ...,  0.4954,  0.4509, -0.1627],
#         ...,
#         [ 0.3509, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0379, -0.2713, -0.2692,  ...,  0.4954,  0.4516, -0.1627],
#         [-0.1529, -0.2713, -0.2694,  ...,  0.1242,  0.0910, -0.1627]])
# Targets:
# tensor([6, 2, 6, 0, 0, 6, 6, 0, 6, 6, 0, 4, 4, 2, 0, 4, 0, 2, 1, 1, 2, 6, 0, 0,
#         4, 6, 0, 0, 6, 0, 0, 4, 3, 2, 0, 2, 4, 2, 6, 3, 2, 6, 2, 3, 4, 2, 2, 0,
#         6, 0, 5, 3, 0, 2, 6, 4, 1, 6, 1, 4, 0, 2, 3, 4, 5, 0, 0, 2, 1, 4, 0, 1,
#         0, 4, 0, 6, 2, 0, 2, 2, 6, 6, 4, 2, 6, 2, 2, 6, 1, 2, 0, 5, 0, 0, 0, 0,
#         6, 0, 6, 2, 0, 6, 0, 6, 0, 6, 0, 2, 6, 2, 3, 6, 6, 2, 6, 0, 0, 1, 1, 0,
#         6, 0, 6, 2, 2, 1, 4, 0, 6, 6, 3, 6, 4, 6, 6, 6, 0, 6, 0, 6, 6, 6, 6, 0,
#         0, 0, 0, 2, 0, 6, 6, 4, 3, 6, 2, 0, 6, 0, 1, 2, 6, 0, 6, 6, 1, 4, 1, 1,
#         0, 1, 3, 0, 6, 6, 5, 1, 6, 0, 0, 2, 6, 0, 6, 1, 3, 2, 1, 4, 6, 3, 2, 0,
#         0, 1, 6, 0, 0, 0, 6, 6, 4, 4, 0, 6, 0, 6, 6, 2, 6, 0, 5, 0, 3, 6, 6, 0,
#         0, 0, 0, 1, 6, 6, 5, 6, 0, 0, 6, 4, 5, 2, 1, 0, 2, 6, 5, 0, 2, 6, 0, 1,
#         5, 0, 1, 1, 6, 1, 4, 4, 2, 6, 1, 1, 4, 5, 0, 3])
# Batch Index: 26
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.5728, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.5130, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.4767,  1.0367,  0.9922,  ..., -0.0290, -0.0574, -0.1627],
#         ...,
#         [ 0.0218, -0.2708, -0.2694,  ...,  0.4954,  0.4509, -0.1627],
#         [ 0.0215, -0.2713, -0.2694,  ...,  0.4880,  0.4437, -0.1627],
#         [-0.1169, -0.2713, -0.2694,  ..., -0.0704, -0.0602,  0.1007]])
# Targets:
# tensor([0, 2, 6, 5, 4, 0, 2, 4, 6, 6, 6, 0, 0, 3, 6, 3, 1, 6, 0, 2, 6, 0, 0, 6,
#         2, 5, 0, 1, 6, 2, 0, 6, 4, 0, 0, 4, 0, 1, 2, 0, 0, 6, 6, 4, 4, 0, 0, 4,
#         1, 6, 1, 6, 2, 0, 0, 1, 6, 4, 0, 4, 1, 0, 4, 6, 3, 0, 1, 5, 1, 1, 1, 2,
#         1, 0, 5, 2, 2, 2, 5, 2, 2, 0, 2, 6, 6, 1, 0, 6, 6, 2, 2, 2, 0, 0, 6, 6,
#         0, 2, 0, 0, 6, 6, 6, 0, 0, 4, 2, 1, 4, 6, 2, 6, 6, 4, 0, 1, 4, 2, 1, 1,
#         2, 2, 0, 0, 1, 0, 6, 0, 6, 0, 2, 6, 6, 6, 5, 5, 6, 0, 4, 0, 4, 0, 1, 2,
#         3, 0, 0, 2, 0, 2, 5, 0, 6, 6, 2, 4, 4, 6, 2, 4, 0, 5, 0, 1, 2, 4, 3, 6,
#         1, 0, 6, 5, 6, 0, 0, 0, 2, 1, 6, 5, 6, 1, 0, 2, 0, 1, 4, 1, 6, 0, 6, 6,
#         0, 2, 0, 6, 4, 2, 6, 5, 6, 6, 6, 6, 4, 1, 2, 6, 6, 1, 1, 3, 2, 2, 2, 1,
#         3, 6, 0, 6, 4, 4, 6, 1, 6, 4, 5, 1, 5, 0, 2, 6, 0, 2, 6, 2, 6, 4, 1, 0,
#         1, 1, 6, 0, 0, 0, 2, 0, 0, 5, 0, 6, 6, 0, 0, 0])
# Batch Index: 27
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3615, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3483, -0.2713, -0.2694,  ...,  0.3388,  0.2991, -0.1627],
#         [ 0.3619, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.3389, -0.2713, -0.2692,  ...,  0.0116,  0.1707,  0.6141],
#         [-0.6612, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.2904, -0.2087, -0.2108,  ...,  0.1427,  0.1090, -0.1627]])
# Targets:
# tensor([6, 2, 6, 2, 3, 0, 1, 5, 0, 2, 6, 0, 2, 6, 4, 0, 0, 2, 0, 2, 6, 1, 6, 1,
#         2, 4, 6, 2, 0, 3, 6, 5, 6, 4, 6, 0, 0, 6, 0, 0, 1, 0, 5, 5, 5, 4, 0, 0,
#         3, 0, 2, 2, 4, 5, 4, 3, 6, 2, 6, 6, 1, 2, 0, 1, 0, 4, 6, 6, 2, 6, 0, 6,
#         2, 1, 0, 0, 1, 0, 4, 0, 0, 5, 6, 6, 0, 0, 0, 6, 6, 6, 6, 0, 5, 3, 0, 6,
#         6, 2, 0, 4, 0, 0, 1, 2, 4, 6, 0, 0, 1, 6, 1, 2, 0, 2, 6, 6, 6, 2, 2, 6,
#         6, 3, 2, 0, 6, 0, 1, 2, 0, 6, 6, 6, 1, 6, 0, 1, 2, 6, 6, 1, 1, 6, 2, 2,
#         0, 0, 4, 6, 0, 5, 6, 0, 6, 6, 1, 4, 5, 6, 4, 4, 5, 6, 0, 1, 2, 4, 6, 1,
#         3, 6, 6, 6, 6, 0, 0, 0, 2, 2, 6, 6, 2, 6, 6, 2, 1, 6, 6, 0, 3, 2, 6, 0,
#         4, 6, 2, 2, 0, 1, 4, 3, 6, 4, 2, 6, 4, 2, 6, 2, 5, 6, 5, 4, 4, 3, 0, 4,
#         6, 0, 2, 1, 6, 2, 4, 2, 6, 5, 6, 6, 1, 6, 6, 0, 0, 6, 1, 6, 6, 0, 0, 4,
#         2, 0, 2, 0, 6, 2, 6, 3, 6, 4, 0, 2, 4, 2, 4, 1])
# Batch Index: 28
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6621, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 9.2465, -0.2711, -0.2694,  ..., 10.2921,  9.9661, -0.1627],
#         [ 0.3617, -0.2713, -0.2691,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.3620, -0.2712, -0.2693,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3618, -0.2645, -0.2669,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([0, 0, 6, 6, 6, 5, 6, 0, 6, 6, 2, 4, 6, 3, 0, 3, 6, 2, 2, 1, 0, 6, 2, 6,
#         0, 3, 5, 0, 0, 6, 1, 1, 1, 4, 1, 6, 4, 3, 0, 6, 3, 5, 6, 2, 0, 6, 6, 0,
#         5, 0, 6, 0, 6, 2, 2, 0, 5, 0, 1, 6, 1, 2, 2, 6, 4, 0, 0, 6, 0, 6, 0, 1,
#         1, 1, 6, 0, 3, 6, 0, 1, 0, 6, 5, 1, 4, 2, 3, 6, 6, 3, 6, 2, 6, 2, 2, 6,
#         4, 2, 6, 0, 2, 6, 6, 0, 0, 1, 1, 1, 1, 6, 2, 2, 3, 0, 1, 2, 6, 0, 3, 6,
#         6, 0, 0, 2, 6, 1, 6, 2, 4, 6, 0, 1, 1, 0, 2, 0, 3, 4, 2, 4, 0, 0, 0, 5,
#         0, 5, 1, 0, 2, 2, 4, 2, 0, 6, 5, 2, 3, 0, 0, 4, 0, 2, 3, 2, 0, 1, 4, 2,
#         1, 2, 5, 1, 2, 0, 6, 6, 4, 6, 0, 2, 0, 5, 0, 0, 4, 2, 5, 6, 0, 6, 0, 5,
#         2, 6, 2, 3, 5, 5, 0, 6, 0, 0, 4, 6, 6, 2, 0, 2, 6, 1, 0, 1, 1, 3, 2, 2,
#         6, 6, 6, 4, 6, 6, 6, 6, 0, 1, 3, 0, 2, 0, 1, 1, 6, 0, 1, 3, 0, 0, 0, 6,
#         6, 6, 6, 6, 1, 0, 3, 0, 6, 6, 4, 3, 4, 6, 6, 4])
# Batch Index: 29
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0199,  4.2039,  4.0458,  ...,  0.4954,  0.4508, -0.1627],
#         [-0.6243,  0.0901,  0.0791,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.5464, -0.2713, -0.1323,  ..., -0.1415, -0.1664, -0.1627],
#         [-0.0480, -0.2713, -0.2689,  ...,  0.1227,  0.0896, -0.1627],
#         [ 0.0200,  4.2043,  4.0464,  ...,  0.4954,  0.4509, -0.1627]])
# Targets:
# tensor([5, 6, 4, 0, 2, 0, 2, 6, 2, 0, 6, 0, 6, 6, 6, 1, 6, 3, 6, 2, 6, 5, 0, 6,
#         0, 1, 6, 2, 6, 6, 2, 0, 6, 0, 0, 0, 4, 2, 2, 0, 0, 6, 0, 2, 4, 0, 0, 6,
#         0, 2, 3, 1, 2, 6, 2, 6, 4, 6, 6, 6, 1, 1, 6, 6, 2, 6, 6, 0, 4, 0, 0, 5,
#         4, 2, 2, 1, 6, 6, 4, 4, 0, 2, 6, 6, 0, 6, 6, 1, 1, 2, 6, 5, 0, 1, 0, 0,
#         1, 4, 4, 0, 6, 6, 6, 2, 6, 0, 0, 0, 6, 1, 6, 0, 1, 3, 1, 6, 6, 2, 6, 5,
#         4, 0, 6, 4, 6, 6, 1, 6, 4, 0, 1, 6, 1, 3, 1, 1, 4, 0, 5, 0, 6, 2, 6, 3,
#         6, 0, 0, 0, 4, 0, 6, 6, 0, 4, 0, 1, 2, 0, 4, 0, 0, 0, 2, 2, 6, 6, 6, 0,
#         0, 4, 6, 2, 0, 0, 2, 4, 1, 0, 6, 0, 0, 0, 6, 0, 0, 4, 0, 4, 2, 2, 5, 2,
#         6, 0, 2, 6, 6, 6, 6, 2, 6, 5, 5, 0, 6, 2, 6, 6, 0, 6, 0, 6, 5, 0, 6, 1,
#         6, 5, 0, 0, 4, 6, 4, 6, 0, 1, 3, 2, 1, 0, 1, 2, 1, 0, 0, 2, 6, 2, 6, 1,
#         6, 0, 0, 0, 6, 4, 0, 2, 4, 0, 1, 2, 0, 2, 3, 6])
# Batch Index: 30
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3233,  0.1563,  0.1395,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.1068, -0.2712, -0.2611,  ...,  0.3282,  0.2888, -0.1627],
#         [-0.5691, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.3338, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6614, -0.1476, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3400, -0.2713, -0.2694,  ..., -0.0705,  0.0230,  0.2520]])
# Targets:
# tensor([6, 0, 5, 1, 1, 5, 4, 2, 6, 0, 6, 1, 2, 0, 4, 1, 4, 0, 3, 0, 6, 0, 4, 6,
#         6, 3, 6, 0, 6, 1, 0, 6, 5, 1, 0, 4, 6, 4, 2, 1, 6, 0, 5, 4, 5, 0, 0, 0,
#         1, 2, 2, 1, 0, 5, 6, 1, 0, 0, 4, 6, 5, 1, 1, 6, 6, 6, 6, 0, 6, 2, 5, 0,
#         0, 3, 6, 6, 0, 6, 3, 6, 6, 3, 2, 6, 6, 0, 1, 2, 0, 0, 5, 6, 6, 3, 6, 6,
#         1, 6, 6, 0, 4, 1, 2, 3, 0, 0, 2, 1, 6, 3, 0, 1, 0, 3, 4, 3, 2, 6, 1, 6,
#         1, 2, 0, 2, 2, 1, 4, 1, 6, 0, 6, 6, 0, 6, 5, 6, 0, 6, 6, 0, 6, 1, 6, 1,
#         6, 0, 0, 5, 4, 2, 2, 2, 0, 1, 6, 0, 0, 4, 1, 1, 0, 4, 6, 0, 3, 6, 6, 4,
#         2, 1, 6, 6, 2, 2, 5, 1, 6, 2, 0, 2, 3, 6, 0, 3, 2, 0, 1, 1, 6, 2, 6, 0,
#         0, 6, 0, 4, 6, 5, 2, 1, 4, 1, 6, 0, 0, 4, 0, 5, 0, 5, 0, 6, 2, 6, 0, 6,
#         6, 4, 2, 3, 0, 0, 0, 4, 2, 0, 3, 6, 1, 4, 6, 0, 6, 6, 2, 6, 2, 0, 6, 6,
#         3, 0, 0, 6, 2, 4, 5, 1, 5, 1, 0, 1, 2, 2, 0, 0])
# Batch Index: 31
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.0658, -0.2093, -0.2692,  ...,  0.0538,  0.0661,  0.1420],
#         [-0.6805, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.0222, -0.2713, -0.2694,  ...,  0.4167,  0.3746, -0.1627],
#         [ 0.3531, -0.2714, -0.2694,  ..., -0.1517, -0.1645, -0.1189],
#         [ 0.0299, -0.2712, -0.2694,  ...,  0.4953,  0.4508, -0.1627]])
# Targets:
# tensor([1, 2, 2, 0, 6, 1, 0, 0, 2, 6, 6, 0, 4, 0, 3, 6, 0, 6, 0, 1, 2, 2, 0, 2,
#         1, 2, 0, 5, 1, 1, 0, 5, 0, 5, 6, 6, 2, 3, 4, 2, 6, 6, 1, 6, 6, 0, 0, 2,
#         6, 3, 6, 4, 6, 0, 0, 6, 2, 1, 1, 6, 0, 6, 2, 0, 0, 0, 2, 0, 2, 6, 6, 2,
#         1, 5, 0, 0, 0, 6, 6, 6, 2, 1, 5, 0, 6, 6, 0, 0, 2, 0, 6, 6, 6, 4, 1, 0,
#         0, 0, 2, 6, 3, 6, 0, 4, 6, 0, 1, 0, 2, 2, 0, 6, 6, 6, 6, 0, 6, 1, 0, 0,
#         4, 0, 0, 0, 0, 1, 1, 2, 4, 6, 3, 0, 0, 0, 6, 0, 0, 1, 4, 5, 6, 4, 1, 1,
#         6, 0, 0, 2, 5, 1, 4, 2, 0, 2, 1, 0, 0, 3, 6, 0, 2, 2, 6, 6, 6, 3, 4, 0,
#         1, 2, 0, 1, 2, 2, 2, 6, 1, 2, 6, 0, 0, 2, 0, 2, 6, 0, 6, 4, 4, 4, 0, 1,
#         0, 0, 5, 0, 6, 5, 6, 2, 2, 6, 0, 6, 1, 2, 1, 2, 1, 2, 6, 0, 0, 6, 0, 6,
#         0, 6, 6, 0, 0, 6, 6, 4, 4, 5, 0, 2, 0, 6, 6, 1, 6, 6, 6, 6, 2, 1, 0, 2,
#         6, 0, 6, 2, 1, 6, 6, 6, 2, 6, 0, 5, 0, 0, 0, 0])
# Batch Index: 32
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3612, -0.2710, -0.2694,  ...,  0.1017,  0.1351,  0.3015],
#         [ 0.3621, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3617, -0.2688, -0.2627,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3527, -0.2710, -0.2683,  ..., -0.0625, -0.0150,  0.1981],
#         [ 0.1044, -0.2713, -0.2694,  ..., -0.0270,  0.0672,  0.4857]])
# Targets:
# tensor([3, 6, 6, 0, 2, 0, 4, 5, 0, 6, 3, 5, 2, 0, 0, 1, 1, 0, 0, 0, 6, 0, 0, 1,
#         3, 0, 0, 6, 4, 6, 0, 2, 4, 6, 1, 6, 6, 2, 4, 2, 1, 2, 6, 5, 0, 0, 6, 2,
#         5, 0, 6, 0, 4, 0, 6, 0, 6, 0, 6, 0, 6, 5, 1, 0, 6, 0, 6, 2, 2, 1, 4, 0,
#         5, 5, 0, 6, 4, 1, 2, 4, 2, 6, 1, 0, 1, 4, 6, 1, 0, 3, 0, 0, 6, 5, 0, 0,
#         0, 4, 0, 6, 0, 1, 0, 4, 4, 0, 5, 0, 6, 0, 0, 0, 2, 2, 1, 0, 2, 6, 6, 6,
#         6, 6, 3, 0, 0, 6, 0, 0, 1, 6, 0, 2, 6, 2, 5, 0, 4, 4, 0, 0, 6, 6, 6, 0,
#         6, 2, 2, 6, 2, 2, 0, 6, 0, 6, 6, 0, 0, 6, 6, 4, 6, 5, 0, 1, 6, 0, 6, 0,
#         0, 2, 2, 0, 0, 0, 2, 2, 6, 4, 1, 6, 0, 0, 6, 0, 0, 5, 0, 2, 6, 6, 2, 4,
#         0, 4, 6, 1, 2, 6, 6, 6, 5, 3, 0, 2, 1, 0, 2, 1, 3, 1, 6, 4, 1, 0, 1, 5,
#         1, 5, 6, 2, 0, 6, 1, 1, 2, 3, 6, 0, 2, 5, 6, 6, 6, 6, 1, 4, 6, 1, 0, 6,
#         0, 4, 6, 6, 1, 2, 0, 6, 0, 2, 6, 0, 6, 4, 1, 0])
# Batch Index: 33
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3610, -0.2688, -0.2627,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0199,  4.2040,  4.0456,  ...,  0.4954,  0.4509, -0.1627],
#         [-0.2761, -0.2713, -0.2694,  ...,  0.1335,  0.1001, -0.1627],
#         ...,
#         [-0.1077, -0.2712, -0.2611,  ...,  0.2960,  0.2576, -0.1627],
#         [ 7.9890, -0.2712, -0.2694,  ...,  9.0304,  8.6908, -0.1627],
#         [ 0.3620, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([6, 6, 0, 6, 1, 0, 2, 2, 3, 1, 4, 4, 0, 0, 6, 0, 0, 6, 0, 1, 2, 1, 3, 6,
#         6, 0, 0, 2, 1, 0, 0, 0, 1, 6, 0, 6, 6, 5, 6, 0, 0, 0, 4, 2, 0, 3, 0, 0,
#         0, 5, 6, 6, 1, 0, 1, 3, 6, 2, 0, 6, 6, 2, 5, 4, 3, 0, 6, 0, 0, 0, 0, 6,
#         4, 4, 2, 6, 6, 6, 6, 2, 6, 4, 2, 6, 1, 6, 6, 0, 2, 0, 1, 4, 0, 1, 6, 4,
#         4, 6, 3, 0, 0, 1, 6, 0, 6, 2, 0, 6, 0, 5, 6, 6, 2, 0, 0, 6, 0, 0, 2, 0,
#         6, 4, 5, 1, 6, 0, 3, 5, 2, 0, 2, 2, 6, 4, 3, 6, 3, 0, 0, 6, 6, 5, 6, 3,
#         0, 0, 6, 0, 5, 5, 2, 0, 6, 6, 5, 6, 4, 2, 6, 6, 6, 4, 2, 0, 0, 3, 0, 0,
#         1, 6, 4, 6, 3, 6, 4, 4, 6, 1, 6, 6, 0, 6, 6, 2, 4, 6, 2, 6, 1, 1, 4, 4,
#         0, 3, 0, 1, 4, 0, 6, 0, 0, 2, 3, 1, 6, 4, 1, 6, 6, 0, 0, 2, 0, 6, 4, 6,
#         0, 6, 6, 6, 2, 3, 4, 6, 4, 0, 2, 0, 2, 2, 4, 5, 3, 6, 1, 1, 6, 1, 6, 0,
#         6, 0, 1, 6, 6, 4, 4, 6, 6, 2, 2, 6, 6, 0, 0, 6])
# Batch Index: 34
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.3559, -0.2713, -0.2674,  ...,  0.0555,  0.1046,  0.4029],
#         [ 0.3620, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.1427, -0.2713, -0.2123,  ..., -0.0668, -0.0582,  0.0897],
#         ...,
#         [-0.5070, -0.2713, -0.2687,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2136, -0.2713, -0.2694,  ...,  0.0501,  0.1134,  0.2469],
#         [-0.6609, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([2, 6, 1, 4, 6, 4, 0, 4, 2, 6, 2, 6, 6, 6, 0, 6, 1, 1, 2, 1, 6, 0, 0, 0,
#         6, 2, 0, 0, 4, 0, 2, 2, 1, 6, 6, 6, 4, 0, 6, 4, 0, 2, 6, 4, 0, 4, 6, 0,
# ...
#         ...,
#         [ 0.3613, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3620, -0.2713, -0.2689,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6424, -0.0258, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([4, 6, 0, 0, 6, 3, 2, 6, 6, 1, 0, 2, 2, 2, 0, 6, 4, 2, 6, 0, 2, 0, 1, 0,
#         0, 4, 2, 5, 0, 6, 6, 0, 2, 0, 6, 6, 2, 2, 6, 6, 6, 0, 6, 2, 6, 5, 0, 0,
#         4, 6, 6, 6, 6, 0, 0, 0, 4, 6, 4, 0, 2, 5, 6, 4, 6, 2, 2, 4, 6, 6, 1, 2,
#         0, 3, 1, 4, 6, 6, 0, 1, 6, 6, 0, 6, 0, 0, 0, 6, 5, 4, 4, 4, 1, 6, 1, 0,
#         4, 0, 2, 1, 6, 5, 6, 4, 4, 0, 1, 0, 6, 2, 0, 4, 1, 6, 2, 6, 6, 0, 6, 5,
#         4, 1, 4, 4, 2, 6, 6, 0, 0, 1, 3, 1, 2, 2, 0, 0, 2, 6, 5, 2, 0, 6, 0, 6,
#         6, 5, 0, 6, 6, 1, 6, 0, 2, 6, 0, 4, 4, 6, 1, 6, 0, 4, 1, 6, 1, 4, 1, 1,
#         0, 2, 6, 6, 2, 5, 5, 0, 3, 6, 0, 0, 6, 4, 5, 6, 5, 0, 5, 0, 4, 0, 6, 0,
#         3, 2, 2, 6, 6, 2, 0, 4, 1, 2, 4, 1, 1, 4, 0, 0, 4, 2, 2, 6, 1, 2, 2, 1,
#         1, 0, 3, 1, 4, 4, 4, 1, 4, 0, 4, 0, 1, 0, 0, 2, 6, 6, 6, 0, 5, 0, 2, 6,
#         6, 0, 6, 3, 6, 4, 6, 6, 6, 1, 6, 1, 0, 6, 6, 4])
# Batch Index: 41
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.0487, -0.2116, -0.2122,  ...,  0.1273,  0.2699,  1.0779],
#         [-0.6677, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0199,  4.2042,  4.0461,  ...,  0.4954,  0.4509, -0.1627],
#         ...,
#         [-0.6666, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.1525, -0.2712, -0.2694,  ...,  0.1884,  0.1533, -0.1627],
#         [ 0.3619, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([1, 4, 6, 6, 6, 6, 6, 0, 1, 0, 6, 6, 0, 4, 2, 1, 6, 3, 6, 2, 5, 0, 2, 6,
#         1, 4, 3, 0, 1, 0, 1, 6, 6, 2, 6, 6, 4, 0, 2, 2, 6, 6, 4, 3, 1, 1, 4, 6,
#         0, 0, 6, 5, 6, 2, 6, 6, 0, 5, 0, 6, 0, 0, 6, 1, 4, 0, 2, 0, 4, 0, 1, 6,
#         4, 2, 1, 6, 0, 6, 2, 6, 2, 2, 0, 6, 6, 1, 2, 4, 6, 4, 0, 2, 0, 0, 6, 0,
#         4, 3, 0, 2, 1, 6, 6, 3, 5, 6, 1, 6, 2, 0, 5, 1, 0, 2, 4, 0, 4, 5, 6, 6,
#         2, 1, 2, 6, 0, 1, 0, 6, 6, 2, 2, 6, 6, 6, 6, 6, 2, 6, 2, 0, 0, 1, 6, 0,
#         4, 6, 0, 4, 6, 2, 6, 6, 4, 1, 6, 6, 1, 0, 6, 6, 2, 3, 1, 0, 5, 4, 2, 4,
#         5, 4, 6, 2, 4, 0, 0, 4, 4, 1, 0, 6, 6, 3, 0, 6, 6, 6, 0, 0, 6, 6, 2, 2,
#         0, 1, 6, 0, 1, 6, 6, 2, 1, 6, 6, 5, 5, 0, 6, 0, 2, 4, 4, 0, 6, 0, 6, 0,
#         6, 6, 1, 2, 6, 0, 4, 1, 6, 4, 0, 6, 3, 4, 6, 0, 6, 0, 0, 6, 0, 6, 0, 2,
#         0, 1, 0, 0, 6, 6, 6, 0, 0, 6, 2, 6, 1, 4, 2, 6])
# Batch Index: 42
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.5252, -0.2711, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3618, -0.2689, -0.2627,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3619, -0.2686, -0.2679,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.5314, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3616, -0.1768,  6.0844,  ...,  0.8368,  0.7796, -0.1627],
#         [ 0.3019, -0.2489, -0.1620,  ...,  0.0373,  0.0068, -0.1627]])
# Targets:
# tensor([3, 6, 6, 2, 0, 2, 2, 0, 2, 1, 2, 4, 6, 0, 6, 6, 6, 0, 1, 6, 2, 2, 0, 2,
#         2, 0, 4, 2, 4, 1, 6, 0, 0, 6, 0, 6, 6, 2, 3, 6, 3, 6, 1, 3, 0, 3, 0, 6,
#         0, 3, 0, 4, 0, 2, 2, 0, 1, 5, 6, 2, 0, 2, 0, 6, 0, 4, 1, 1, 0, 5, 6, 0,
#         6, 6, 2, 5, 0, 5, 4, 0, 6, 2, 1, 0, 5, 1, 0, 2, 4, 4, 4, 6, 6, 6, 5, 6,
#         4, 2, 6, 6, 4, 5, 0, 4, 0, 0, 6, 0, 6, 1, 0, 4, 2, 4, 2, 6, 3, 6, 1, 4,
#         4, 3, 2, 6, 3, 0, 5, 0, 3, 0, 5, 6, 2, 0, 0, 5, 2, 1, 6, 6, 0, 0, 6, 0,
#         4, 6, 2, 0, 5, 4, 0, 6, 0, 0, 5, 6, 0, 6, 4, 0, 2, 0, 0, 5, 6, 4, 0, 6,
#         1, 1, 5, 4, 6, 0, 0, 2, 0, 0, 1, 0, 6, 4, 1, 1, 6, 4, 0, 0, 6, 0, 0, 0,
#         6, 6, 2, 2, 2, 2, 0, 6, 4, 2, 0, 1, 0, 3, 1, 0, 0, 6, 0, 4, 1, 0, 0, 3,
#         6, 2, 0, 4, 2, 5, 0, 4, 2, 0, 2, 0, 1, 4, 5, 2, 0, 6, 6, 5, 2, 0, 2, 5,
#         4, 2, 6, 6, 4, 4, 6, 5, 1, 3, 1, 1, 1, 2, 0, 2])
# Batch Index: 43
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6319, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0311, -0.2713, -0.2691,  ...,  0.4954,  0.4515, -0.1627],
#         [-0.6614, -0.1473, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.3601, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.1939, -0.2714, -0.2694,  ..., -0.0700, -0.0492,  0.2422],
#         [ 0.3235,  0.1564,  0.1423,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([3, 0, 0, 0, 4, 6, 0, 6, 1, 4, 6, 6, 3, 2, 5, 2, 1, 2, 0, 6, 0, 4, 6, 6,
#         6, 6, 0, 0, 0, 0, 6, 1, 6, 0, 4, 4, 6, 2, 0, 6, 2, 6, 0, 2, 2, 0, 6, 6,
#         1, 3, 2, 5, 1, 0, 6, 2, 6, 2, 0, 2, 0, 5, 2, 5, 4, 6, 0, 0, 2, 1, 0, 0,
#         1, 4, 6, 0, 6, 0, 1, 2, 6, 4, 4, 6, 0, 6, 6, 3, 2, 2, 0, 2, 4, 5, 6, 0,
#         0, 6, 0, 3, 5, 2, 0, 1, 2, 5, 0, 6, 1, 0, 2, 4, 0, 6, 2, 0, 4, 6, 1, 3,
#         2, 1, 0, 6, 2, 6, 2, 4, 6, 1, 0, 1, 0, 2, 5, 0, 1, 1, 0, 2, 2, 5, 0, 6,
#         0, 1, 0, 6, 2, 6, 2, 2, 2, 3, 2, 6, 6, 3, 1, 0, 6, 2, 4, 1, 0, 4, 0, 5,
#         0, 1, 6, 6, 2, 1, 4, 0, 4, 1, 1, 6, 0, 6, 1, 0, 6, 0, 2, 3, 1, 1, 6, 6,
#         1, 5, 0, 0, 0, 0, 1, 6, 1, 1, 4, 5, 0, 2, 0, 0, 6, 0, 3, 6, 4, 6, 0, 2,
#         1, 3, 0, 0, 0, 0, 1, 6, 6, 4, 1, 6, 0, 4, 6, 6, 0, 4, 6, 6, 2, 4, 6, 6,
#         0, 0, 5, 2, 0, 0, 4, 6, 3, 2, 1, 2, 2, 5, 0, 6])
# Batch Index: 44
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[ 0.2934, -0.2712, -0.2690,  ...,  0.2713,  0.3089,  0.3682],
#         [ 0.3601, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.1688, -0.2713, -0.2694,  ...,  0.5325,  0.4861, -0.1627],
#         ...,
#         [ 0.2301, -0.2713, -0.2694,  ..., -0.0786, -0.0117,  0.2120],
#         [-0.6707, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3347, -0.2714, -0.2694,  ..., -0.0483, -0.0007,  0.1000]])
# Targets:
# tensor([2, 5, 2, 0, 2, 3, 6, 1, 4, 4, 5, 6, 4, 6, 6, 2, 0, 4, 0, 2, 1, 1, 6, 6,
#         6, 3, 2, 2, 0, 5, 4, 1, 1, 1, 1, 2, 2, 0, 2, 0, 6, 2, 1, 0, 0, 2, 1, 2,
#         5, 4, 6, 1, 0, 6, 0, 5, 0, 6, 1, 0, 2, 2, 2, 0, 6, 6, 0, 0, 0, 0, 0, 0,
#         0, 0, 2, 0, 4, 0, 0, 6, 1, 0, 3, 1, 4, 2, 6, 2, 0, 4, 0, 1, 4, 2, 6, 4,
#         6, 4, 6, 5, 6, 4, 0, 1, 4, 0, 0, 6, 0, 6, 0, 0, 4, 0, 2, 0, 6, 6, 2, 1,
#         0, 6, 6, 0, 3, 0, 0, 6, 5, 0, 2, 1, 6, 6, 1, 0, 0, 6, 0, 0, 2, 6, 0, 6,
#         6, 6, 4, 2, 4, 6, 6, 2, 6, 2, 6, 6, 0, 5, 1, 2, 5, 1, 0, 1, 5, 4, 5, 2,
#         6, 2, 4, 0, 6, 2, 0, 6, 1, 4, 1, 6, 0, 0, 6, 0, 4, 2, 2, 0, 6, 0, 0, 3,
#         0, 1, 4, 4, 6, 6, 5, 6, 2, 0, 3, 6, 6, 2, 6, 6, 5, 0, 0, 6, 6, 1, 2, 2,
#         4, 6, 6, 2, 2, 2, 3, 6, 0, 4, 0, 6, 1, 6, 0, 0, 6, 1, 0, 2, 2, 5, 5, 1,
#         3, 0, 1, 2, 1, 4, 6, 5, 0, 0, 0, 0, 3, 0, 2, 1])
# Batch Index: 45
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6789, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3614, -0.2713, -0.2669,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3608, -0.2713, -0.2690,  ...,  0.4947,  0.4501, -0.1627],
#         ...,
#         [ 0.3618, -0.2698, -0.2686,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2963, -0.2582, -0.2568,  ..., -0.1488, -0.1589, -0.0871],
#         [ 0.0313, -0.2713, -0.2694,  ..., -0.0125,  0.0879,  0.4389]])
# Targets:
# tensor([3, 6, 3, 2, 6, 6, 6, 6, 2, 4, 0, 2, 0, 6, 5, 2, 1, 0, 0, 4, 6, 1, 0, 2,
#         0, 2, 6, 0, 1, 0, 6, 0, 0, 6, 6, 0, 6, 0, 2, 0, 2, 2, 5, 6, 4, 0, 4, 5,
#         0, 2, 2, 6, 2, 3, 0, 6, 2, 4, 4, 4, 6, 6, 4, 0, 2, 0, 4, 1, 6, 0, 2, 6,
#         0, 0, 0, 0, 6, 0, 6, 0, 2, 1, 0, 5, 2, 6, 0, 0, 2, 6, 6, 3, 6, 6, 1, 0,
#         1, 1, 4, 5, 0, 6, 2, 0, 2, 2, 0, 0, 1, 1, 2, 6, 2, 2, 1, 6, 0, 2, 0, 2,
#         1, 6, 0, 4, 6, 6, 0, 1, 0, 6, 6, 2, 0, 5, 2, 5, 6, 0, 0, 4, 0, 6, 6, 0,
#         1, 2, 2, 2, 6, 6, 0, 4, 6, 2, 3, 0, 6, 0, 2, 2, 1, 4, 6, 4, 6, 6, 1, 2,
#         2, 6, 0, 1, 6, 2, 4, 2, 1, 0, 6, 0, 0, 4, 3, 5, 2, 1, 3, 3, 0, 1, 0, 6,
#         0, 2, 1, 2, 1, 0, 0, 3, 0, 6, 0, 1, 0, 1, 4, 6, 0, 1, 6, 5, 4, 0, 2, 6,
#         6, 4, 0, 1, 0, 5, 2, 0, 0, 2, 2, 3, 6, 2, 1, 6, 2, 6, 5, 6, 6, 0, 6, 4,
#         1, 6, 2, 2, 1, 5, 4, 1, 1, 1, 6, 6, 6, 6, 1, 0])
# Batch Index: 46
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6807, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.5407, -0.2713, -0.2694,  ..., -0.1113, -0.1372, -0.1627],
#         [ 0.2991, -0.2713, -0.2694,  ...,  0.1520,  0.1537,  0.0893],
#         ...,
#         [ 0.0199,  4.2040,  4.0458,  ...,  0.4954,  0.4509, -0.1627],
#         [ 0.3234,  0.1563,  0.1428,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0470, -0.2712, -0.2694,  ...,  0.4770,  0.4331, -0.1627]])
# Targets:
# tensor([4, 0, 0, 1, 1, 4, 4, 6, 6, 0, 2, 0, 1, 3, 6, 4, 2, 6, 6, 0, 1, 4, 6, 2,
#         1, 4, 6, 5, 0, 6, 1, 5, 3, 2, 6, 2, 1, 6, 2, 5, 6, 2, 0, 1, 2, 2, 0, 2,
#         2, 2, 6, 6, 6, 6, 6, 6, 6, 1, 6, 4, 1, 0, 6, 3, 2, 6, 6, 4, 0, 2, 1, 2,
#         6, 6, 2, 1, 0, 6, 0, 5, 6, 4, 2, 1, 0, 0, 2, 2, 6, 0, 6, 5, 0, 4, 1, 1,
#         2, 6, 0, 6, 2, 1, 4, 0, 4, 0, 0, 0, 6, 1, 4, 0, 4, 0, 2, 3, 1, 0, 4, 5,
#         0, 2, 1, 2, 0, 2, 6, 0, 0, 0, 1, 6, 4, 6, 5, 0, 0, 3, 2, 1, 6, 0, 6, 6,
#         2, 6, 2, 5, 4, 6, 0, 0, 6, 3, 3, 3, 6, 0, 0, 3, 3, 6, 2, 1, 0, 4, 6, 1,
#         4, 1, 1, 1, 5, 1, 0, 0, 0, 5, 2, 0, 6, 0, 2, 6, 1, 0, 2, 2, 2, 4, 0, 2,
#         6, 6, 1, 6, 6, 6, 4, 0, 4, 5, 4, 4, 0, 0, 6, 4, 5, 0, 6, 0, 3, 2, 6, 2,
#         3, 0, 6, 0, 1, 6, 2, 4, 2, 2, 6, 6, 1, 0, 1, 2, 5, 0, 6, 4, 0, 5, 5, 3,
#         3, 3, 6, 0, 6, 0, 6, 0, 4, 6, 4, 0, 1, 6, 6, 5])
# Batch Index: 47
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.1205, -0.2713, -0.2694,  ...,  0.2384,  0.2018, -0.1627],
#         [-0.6696, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3223,  0.1567,  0.1432,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [ 0.3620, -0.2660, -0.2677,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3325, -0.2713, -0.2694,  ..., -0.1615, -0.1756, -0.1337],
#         [ 0.3608, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([2, 4, 6, 1, 6, 0, 3, 6, 0, 6, 6, 4, 6, 0, 0, 4, 0, 1, 0, 1, 6, 4, 1, 0,
#         4, 1, 1, 6, 1, 2, 0, 0, 6, 1, 0, 2, 0, 0, 6, 2, 5, 0, 4, 0, 2, 6, 0, 0,
#         0, 6, 2, 4, 0, 2, 1, 6, 1, 2, 4, 5, 6, 6, 4, 1, 4, 6, 4, 2, 2, 2, 2, 4,
#         1, 6, 6, 1, 0, 6, 6, 0, 6, 6, 6, 1, 6, 6, 6, 1, 0, 6, 0, 2, 1, 4, 5, 3,
#         6, 4, 6, 6, 6, 6, 4, 0, 0, 6, 6, 0, 1, 6, 4, 2, 1, 6, 4, 6, 2, 2, 1, 1,
#         0, 1, 4, 6, 0, 3, 2, 6, 2, 2, 6, 3, 6, 0, 2, 6, 0, 6, 5, 6, 1, 3, 2, 1,
#         0, 3, 6, 3, 5, 6, 6, 6, 1, 4, 6, 1, 6, 0, 4, 6, 0, 6, 6, 6, 6, 2, 1, 1,
#         4, 0, 4, 0, 4, 4, 2, 6, 0, 2, 0, 0, 6, 5, 0, 2, 2, 1, 0, 3, 2, 0, 6, 6,
#         2, 6, 6, 2, 5, 2, 6, 1, 1, 2, 6, 0, 6, 6, 6, 6, 1, 6, 2, 6, 0, 0, 2, 5,
#         6, 6, 5, 6, 2, 0, 1, 6, 1, 0, 6, 0, 1, 1, 4, 6, 2, 4, 1, 0, 2, 2, 0, 2,
#         6, 0, 2, 2, 2, 6, 2, 0, 2, 0, 0, 2, 6, 6, 1, 6])
# Batch Index: 48
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.3069, -0.2713, -0.1447,  ...,  0.1188,  0.0859, -0.1627],
#         [ 0.3550, -0.2713, -0.2693,  ..., -0.1279, -0.1532, -0.1627],
#         [ 0.2842, -0.2713, -0.2694,  ...,  0.2375,  0.3257,  0.7185],
#         ...,
#         [-0.6687, -0.1942, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.0198,  4.2039,  4.0458,  ...,  0.4954,  0.4509, -0.1627],
#         [ 0.3233,  0.1564,  0.1429,  ..., -0.2468, -0.2685, -0.1627]])
# Targets:
# tensor([2, 2, 1, 6, 0, 5, 6, 2, 0, 6, 1, 5, 1, 4, 6, 4, 6, 3, 6, 0, 1, 0, 0, 6,
#         6, 5, 0, 0, 0, 4, 6, 6, 6, 3, 6, 5, 1, 0, 1, 0, 6, 2, 2, 0, 0, 5, 1, 4,
#         6, 0, 3, 2, 6, 0, 2, 2, 2, 6, 1, 4, 6, 0, 4, 6, 0, 2, 1, 2, 6, 0, 0, 3,
#         1, 5, 3, 0, 6, 6, 3, 6, 0, 0, 6, 0, 5, 6, 0, 0, 1, 6, 6, 0, 5, 6, 3, 0,
#         0, 6, 6, 2, 4, 0, 1, 1, 0, 0, 4, 6, 2, 0, 6, 6, 0, 6, 6, 3, 0, 5, 6, 0,
#         6, 2, 6, 1, 0, 0, 6, 2, 6, 6, 4, 3, 6, 4, 0, 2, 6, 6, 2, 6, 3, 2, 3, 0,
#         2, 0, 6, 2, 6, 0, 2, 1, 6, 6, 6, 2, 6, 1, 6, 2, 6, 1, 1, 4, 6, 2, 0, 6,
#         4, 4, 4, 6, 0, 6, 4, 4, 4, 0, 5, 6, 6, 6, 0, 2, 6, 2, 6, 0, 5, 0, 6, 0,
#         2, 6, 0, 6, 5, 6, 5, 0, 4, 1, 0, 1, 6, 0, 2, 6, 0, 3, 4, 6, 5, 6, 0, 4,
#         2, 6, 1, 6, 4, 0, 6, 0, 1, 1, 5, 0, 5, 1, 0, 6, 0, 1, 1, 0, 4, 1, 6, 1,
#         0, 6, 6, 6, 5, 6, 4, 1, 6, 6, 6, 5, 6, 3, 6, 6])
# Batch Index: 49
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-0.6807, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6696, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3116, -0.2713, -0.2694,  ...,  0.7848,  0.7341, -0.1627],
#         ...,
#         [-0.6671, -0.2710, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6619, -0.1508, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.3616, -0.2714, -0.2694,  ...,  0.2390,  0.4034,  1.2558]])
# Targets:
# tensor([1, 2, 0, 2, 0, 4, 0, 6, 1, 0, 4, 0, 0, 0, 4, 6, 0, 0, 0, 5, 2, 6, 6, 6,
#         0, 6, 6, 6, 6, 1, 1, 6, 0, 2, 6, 4, 3, 6, 1, 0, 2, 6, 6, 4, 2, 2, 6, 4,
#         6, 0, 1, 0, 0, 6, 0, 2, 0, 4, 2, 4, 2, 2, 1, 6, 6, 6, 1, 2, 6, 6, 6, 4,
#         2, 1, 1, 6, 6, 2, 4, 1, 0, 1, 6, 6, 6, 1, 6, 3, 5, 2, 4, 6, 5, 0, 2, 6,
#         2, 1, 1, 0, 0, 0, 6, 5, 6, 4, 6, 6, 4, 0, 0, 6, 4, 6, 0, 0, 0, 0, 4, 0,
#         6, 2, 0, 1, 6, 4, 0, 1, 6, 5, 1, 0, 6, 2, 1, 4, 0, 6, 6, 6, 4, 0, 1, 0,
#         0, 1, 2, 2, 6, 6, 4, 0, 6, 0, 6, 0, 6, 2, 6, 1, 0, 0, 4, 2, 5, 4, 2, 1,
#         6, 4, 2, 6, 0, 0, 2, 0, 1, 4, 6, 0, 2, 1, 0, 6, 3, 3, 0, 2, 0, 4, 6, 2,
#         6, 4, 1, 0, 6, 6, 2, 1, 3, 2, 4, 6, 6, 1, 6, 6, 4, 2, 6, 2, 6, 1, 6, 0,
#         3, 6, 6, 6, 6, 6, 4, 0, 4, 0, 0, 6, 2, 0, 6, 2, 2, 0, 6, 6, 6, 4, 4, 1,
#         0, 1, 6, 2, 0, 2, 2, 6, 0, 5, 6, 2, 0, 0, 2, 0])
# Batch Index: 50
# Input sizes: torch.Size([256, 23])
# Target sizes: torch.Size([256])
# Inputs:
# tensor([[-4.6461e-01,  1.1145e+00,  1.0664e+00,  ..., -1.6145e-02,
#          -4.4950e-02, -1.6268e-01],
#         [ 3.2237e-01,  1.5626e-01,  1.4274e-01,  ..., -2.4678e-01,
#          -2.6850e-01, -1.6268e-01],
#         [ 2.7845e-01, -2.7133e-01, -2.6941e-01,  ...,  7.3289e-01,
#           6.8020e-01, -1.6268e-01],
#         ...,
#         [-2.8943e-01, -2.7134e-01, -2.6942e-01,  ..., -2.4678e-01,
#          -2.6850e-01, -1.6268e-01],
#         [-6.7669e-01, -2.7135e-01, -2.6942e-01,  ..., -2.4678e-01,
#          -2.6850e-01, -1.6268e-01],
#         [ 6.9553e+00, -2.7130e-01, -2.6940e-01,  ...,  3.6496e+00,
#           7.2144e+00,  2.5973e+01]])
# Targets:
# tensor([6, 6, 0, 6, 6, 4, 1, 2, 6, 3, 2, 1, 2, 6, 6, 4, 5, 0, 6, 6, 5, 4, 1, 5,
#         3, 0, 1, 0, 1, 1, 0, 0, 6, 0, 2, 3, 0, 2, 2, 0, 2, 0, 6, 0, 0, 6, 5, 2,
#         2, 6, 2, 6, 4, 2, 1, 6, 0, 1, 4, 1, 0, 0, 2, 0, 2, 0, 0, 0, 0, 4, 5, 6,
#         6, 6, 6, 0, 4, 0, 0, 0, 5, 4, 2, 6, 6, 6, 1, 0, 1, 6, 6, 0, 4, 0, 0, 6,
#         2, 3, 6, 5, 1, 0, 0, 6, 0, 6, 4, 0, 0, 0, 4, 1, 3, 2, 6, 0, 0, 1, 0, 6,
#         6, 0, 6, 0, 0, 2, 0, 0, 4, 6, 4, 2, 3, 6, 2, 3, 0, 0, 4, 0, 2, 3, 6, 2,
#         4, 1, 6, 0, 6, 2, 0, 3, 2, 0, 0, 0, 0, 6, 0, 2, 6, 6, 0, 0, 4, 4, 0, 2,
#         6, 6, 2, 6, 4, 6, 0, 6, 6, 0, 6, 0, 1, 0, 1, 0, 6, 1, 2, 1, 6, 0, 0, 6,
#         2, 6, 6, 4, 6, 4, 6, 2, 2, 1, 6, 5, 6, 0, 4, 5, 0, 6, 0, 0, 5, 0, 0, 6,
#         0, 6, 2, 3, 0, 2, 0, 5, 0, 2, 0, 0, 6, 2, 6, 6, 1, 6, 0, 4, 6, 2, 1, 6,
#         0, 3, 0, 6, 4, 0, 0, 6, 6, 2, 1, 6, 5, 4, 1, 0])
# Batch Index: 51
# Input sizes: torch.Size([74, 23])
# Target sizes: torch.Size([74])
# Inputs:
# tensor([[-0.4617, -0.2713, -0.2694,  ..., -0.0265, -0.0550, -0.1627],
#         [-0.6580, -0.2714, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [-0.6621, -0.1516, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         ...,
#         [-0.1771, -0.2489, -0.1858,  ..., -0.0612, -0.0154,  0.3543],
#         [ 0.3613, -0.2713, -0.2694,  ..., -0.2468, -0.2685, -0.1627],
#         [ 0.2417, -0.2713, -0.2694,  ..., -0.0818, -0.0919, -0.0624]])
# Targets:
# tensor([0, 2, 2, 0, 4, 0, 0, 1, 5, 6, 4, 1, 4, 0, 0, 4, 2, 6, 5, 4, 2, 6, 0, 6,
#         2, 4, 4, 1, 6, 6, 0, 6, 6, 2, 4, 2, 6, 6, 0, 6, 0, 2, 5, 5, 1, 0, 0, 0,
#         0, 2, 0, 6, 1, 6, 2, 0, 0, 2, 0, 1, 0, 0, 0, 1, 1, 2, 0, 1, 0, 1, 3, 2,
#         6, 5])

# %% [markdown]
# # Interpretable Transformer Design
#
# ##

# %%
class SelfAttention(nn.Module):
    def __init__(self, embed_size, heads):
        super(SelfAttention, self).__init__()

        self.embed_size = embed_size
        self.heads = heads
        self.head_dim = embed_size // heads
        assert(self.head_dim * heads == embed_size), "Embed size needs to be div by heads"
        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.keys =nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.fc_out = nn.Linear(heads*self.head_dim, embed_size)


    def forward(self, values, keys, query):
        N = query.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], query.shape[1]

        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = query.reshape(N, key_len, self.heads, self.head_dim)

        values = self.values(values)
        keys = self.keys(keys)
        queries = self.queries(queries)

        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys])
        # print('energy shape ', energy.shape)

        # if mask is not None:
        #     energy = energy.masked_fill(mask == 0, float("-1e20"))

        attention = torch.softmax(energy / (self.embed_size ** (1/2)), dim=3) #(batch_size, head_dim, #query_embeddings, #key_embeddings)

        # Calculate simplified attention scores
        avg_attention = attention[:,:,-1,:] #taking only the attention of the last embedding
        avg_attention = attention.mean(dim=0)  # Average across batches
        avg_attention = avg_attention.mean(dim=1).squeeze(dim=0)  # Average across heads -> (#key_embeddings)

        out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(N, query_len, self.heads*self.head_dim) #(batch_size, n_features, embed_size)
        # print('values shape', values.shape)
        # print('output shape', out.shape)
        out = self.fc_out(out)


        return out, avg_attention
    
class TransformerBlock(nn.Module):
    def __init__(self, embed_size, heads, dropout, forward_expansion):
        super(TransformerBlock, self).__init__()

        self.attention = SelfAttention(embed_size, heads)
        self.norm1 = nn.LayerNorm(embed_size)
        self.norm2 = nn.LayerNorm(embed_size)

        self.feed_forward = nn.Sequential(nn.Linear(embed_size, forward_expansion*embed_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion*embed_size, embed_size)
                                          )
        self.dropout = nn.Dropout(dropout)

    def forward(self,value,key,query):
        attention, avg_attention = self.attention(value, key, query)
        x = self.dropout(self.norm1(attention + query))
        forward = self.feed_forward(x)
        out = self.dropout(self.norm2(forward + x))
        return out, avg_attention

class Encoder(nn.Module):
    def __init__(self,
                 embed_size,
                 num_layers,
                 heads,
                 forward_expansion,
                 encoder_dropout
    ):
        super(Encoder, self).__init__()
        
        self.layers = nn.ModuleList(
            [
                TransformerBlock(
                    embed_size,
                    heads,
                    dropout=encoder_dropout,
                    forward_expansion=forward_expansion
                )
                for _ in range(num_layers)
            ]
        )
        self.avg_attention = None

    def forward(self, x):
        for layer in self.layers:
            #running embeddings through transformer block
            #keys, values, and query are all the same initially (x)
            x, self.avg_attention = layer(x, x, x)
     
        return x #same dimensions as going in

# %%
class Embeddings(nn.Module):
    def __init__(self, sigma, embed_size, input_size, embedding_dropout, n_features, rff_on):
        super(Embeddings, self).__init__()

        self.rff_on = rff_on

        if self.rff_on:
            self.rffs = nn.ModuleList([GaussianEncoding(sigma=sigma, input_size=input_size, encoded_size=embed_size//2) for x in range(n_features)])
            self.dropout = nn.Dropout(embedding_dropout)
            self.mlp_in = embed_size
        else:
            self.mlp_in = input_size

        self.embeddings = nn.ModuleList([nn.Linear(in_features=self.mlp_in, out_features=embed_size) for x in range(n_features)])

    def forward(self, x):
        x = x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)
        rff_vectors = []
        if self.rff_on:
            for i, r in enumerate(self.rffs):
                input = x[:,i,:]
                out = r(input)
                rff_vectors.append(out)
        
            x = torch.stack(rff_vectors, dim=1)
        
        embeddings = []
        for i, e in enumerate(self.embeddings):
            goin_in = x[:,i,:]
            goin_out = e(goin_in)
            embeddings.append(goin_out)

        x = torch.stack(embeddings, dim=1)

        return x

# %%
class classificationHead(nn.Module):
    def __init__(self, n_features, embed_size, dropout, num_target_classes):
        super(classificationHead, self).__init__()
        
        #flattening the embeddings out so each sample in batch is represented with a 460 dimensional vector
        self.n_features = n_features*embed_size
        self.lin1 = nn.Linear(self.n_features, self.n_features)
        self.drop = nn.Dropout(dropout)
        self.lin2 = nn.Linear(self.n_features, num_target_classes)
        
        self.relu = nn.ReLU()
        # self.softmax = nn.Softmax()
        self.initialize_weights()

    def initialize_weights(self): #he_initialization.
        torch.nn.init.kaiming_normal_(self.lin1.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin1.bias)

        torch.nn.init.kaiming_normal_(self.lin2.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin2.bias)

    def forward(self, x):

        x= torch.reshape(x, (-1, self.n_features))

        x = self.lin1(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin2(x)
        # x = self.softmax(x)
        # print(x.shape)
  
        return x

# %%
class LSTM_aggregation(nn.Module):
    def __init__(self, input_size, num_layers, batch_sz):
        super(LSTM_aggregation, self).__init__()
        
        self.embed_size = input_size
        self.num_layers = num_layers
        self.batch_sz = batch_sz
        self.aggregation = nn.LSTM(
                input_size = self.embed_size,
                hidden_size = self.embed_size,
                num_layers = self.num_layers,
                batch_first = True
            )
    def forward(self, x):
        x, _ = self.aggregation(x)
        
        return x

# %%
class vpnClassifier(nn.Module):
    def __init__(self, 
                 rff_on = True,
                 sigma=4,
                 embed_size=20,
                 input_size=1,
                 embedding_dropout = 0,
                 n_features=23,
                 num_layers=2,
                 heads=4,
                 forward_expansion=4,
                 encoder_dropout=0,
                 aggregation_on = True,
                 lstm_layers=1,
                 batch_sz = 256,
                 num_target_classes = 7,
                 classification_dropout = 0
                 ):
        super(vpnClassifier, self).__init__()
        self.aggregation_on = aggregation_on

        self.embeddings = Embeddings(rff_on=rff_on, sigma=sigma, embed_size=embed_size, input_size=input_size, embedding_dropout=embedding_dropout, n_features=n_features)
        self.encoder = Encoder(embed_size=embed_size, num_layers=num_layers, heads=heads, forward_expansion=forward_expansion, encoder_dropout=encoder_dropout)
        if self.aggregation_on:
            self.aggregation = LSTM_aggregation(input_size=embed_size, num_layers=lstm_layers, batch_sz=batch_sz)
        self.classifying_head = classificationHead(n_features=n_features, embed_size=embed_size, dropout=classification_dropout, num_target_classes=num_target_classes)
        
    def forward(self, x):
        x = self.embeddings(x)

        x = self.encoder(x)

        if self.aggregation_on:
            x = self.aggregation(x)
            
        x = self.classifying_head(x)
        return x

# %%
def train(dataloader, model, loss_fn, optimizer, device_in_use):
    model.train()
    total_loss = 0
    total_correct = 0
    total_samples = 0

    for (inputs, targets) in dataloader:
        
        inputs, targets = inputs.to(device_in_use), targets.to(device_in_use)
        # print(batch_idx, inputs, targets)
        pred = model(inputs)
        # print(pred)
        # print(targets)
        # print(pred.squeeze(0))
        loss = loss_fn(pred, targets)
        total_loss+= loss.item()

        # Calculate accuracy
        y_pred_softmax = torch.log_softmax(pred, dim =1)
        _, y_pred_labels = torch.max(y_pred_softmax, dim=1)
        total_correct += (y_pred_labels == targets).sum().item()
        total_samples += targets.size(0)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    avg_loss = total_loss/len(dataloader)
    accuracy = total_correct / total_samples
    return avg_loss, accuracy
    

def test(dataloader, model, loss_fn, device_in_use):
  model.eval()
  tot = 0
  total_correct = 0
  total_samples = 0
  with torch.no_grad():
    for (inputs, targets) in dataloader:
      inputs, targets = inputs.to(device_in_use), targets.to(device_in_use)
      #compute prediction error
      pred = model(inputs)
      test_loss = loss_fn(pred, targets)
      tot += test_loss

      # Calculate accuracy
      y_pred_softmax = torch.log_softmax(pred, dim =1)
      _, y_pred_labels = torch.max(y_pred_softmax, dim=1)
      total_correct += (y_pred_labels == targets).sum().item()
      total_samples += targets.size(0)

  avg = tot/len(dataloader)
  accuracy = total_correct / total_samples

  return avg, accuracy

# %% [markdown]
# # EXPERIMENTS

# %%
#No RFF, No aggregation, 1 encoder layer, no regularization. VERY BASIC


model = vpnClassifier(rff_on=False, num_layers=1, aggregation_on=False, heads=1).to(device_in_use)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(params=model.parameters(), lr=0.0001, momentum=0.9)

epochs = 50
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
all_attention_scores = []
for t in range(epochs):
  train_loss, train_accuracy= train(train_dataloader, model, loss_fn, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy = test(test_dataloader, model, loss_fn, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies.append(train_accuracy)
  test_losses.append(test_loss)
  test_accuracies.append(test_accuracy)
  print(f"Epoch {t+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}")
  

  total_attention = model.encoder.avg_attention
  all_attention_scores.append(total_attention.tolist())
  model.encoder.avg_attention = None


# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l.cpu().numpy() for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

plt.tight_layout()
plt.show()

print(f"Best accuracy: {max(test_accuracies)}")

# Plot attention scores for each feature over epochs

# all_attention_scores = all_attention_scores.cpu().numpy() #CUDA tensor needs to be converted to cpu tensor
all_attention_scores = torch.tensor(all_attention_scores)
plt.figure(figsize=(10, 6))



for feature_idx in range(all_attention_scores.shape[1]):
    plt.plot(all_attention_scores[:, feature_idx], label=df.drop("class1", axis=1).columns[feature_idx])

plt.xlabel('Epochs')
plt.ylabel('Attention Scores')
plt.title('Attention Scores for Each Feature over Epochs')
plt.legend(loc = 'lower left')
plt.show()

last_epoch_attention_scores = all_attention_scores[-1]
top_scores, top_indices = torch.topk(last_epoch_attention_scores, k=10)

# Display the top 10 attention scores and the corresponding feature
for i in range(10):
    print(f"{i+1}. {df.drop('class1', axis=1).columns[int(top_indices[i])]}: {top_scores[i]}")
# Out:
# Epoch 1/50, Train Loss: 1.4070, Test Loss: 1.1240, Train Accuracy: 0.5414, Test Accuracy: 0.5860
# Epoch 2/50, Train Loss: 1.0885, Test Loss: 1.0406, Train Accuracy: 0.6081, Test Accuracy: 0.6160
# Epoch 3/50, Train Loss: 1.0401, Test Loss: 1.0249, Train Accuracy: 0.6335, Test Accuracy: 0.6281
# Epoch 4/50, Train Loss: 1.0268, Test Loss: 1.0135, Train Accuracy: 0.6296, Test Accuracy: 0.6398
# Epoch 5/50, Train Loss: 0.9761, Test Loss: 1.0100, Train Accuracy: 0.6499, Test Accuracy: 0.6349
# Epoch 6/50, Train Loss: 0.9682, Test Loss: 0.9581, Train Accuracy: 0.6477, Test Accuracy: 0.6507
# Epoch 7/50, Train Loss: 0.9339, Test Loss: 0.9650, Train Accuracy: 0.6615, Test Accuracy: 0.6459
# Epoch 8/50, Train Loss: 0.9063, Test Loss: 0.9219, Train Accuracy: 0.6663, Test Accuracy: 0.6604
# Epoch 9/50, Train Loss: 0.8846, Test Loss: 0.8748, Train Accuracy: 0.6703, Test Accuracy: 0.6665
# Epoch 10/50, Train Loss: 0.8793, Test Loss: 0.8858, Train Accuracy: 0.6793, Test Accuracy: 0.6665
# Epoch 11/50, Train Loss: 0.8486, Test Loss: 0.8355, Train Accuracy: 0.6827, Test Accuracy: 0.6773
# Epoch 12/50, Train Loss: 0.8185, Test Loss: 0.8318, Train Accuracy: 0.6880, Test Accuracy: 0.6999
# Epoch 13/50, Train Loss: 0.8065, Test Loss: 0.8367, Train Accuracy: 0.6976, Test Accuracy: 0.6955
# Epoch 14/50, Train Loss: 0.8052, Test Loss: 0.8124, Train Accuracy: 0.7009, Test Accuracy: 0.6995
# Epoch 15/50, Train Loss: 0.7858, Test Loss: 0.7935, Train Accuracy: 0.7036, Test Accuracy: 0.7123
# Epoch 16/50, Train Loss: 0.7956, Test Loss: 0.8170, Train Accuracy: 0.7023, Test Accuracy: 0.6626
# Epoch 17/50, Train Loss: 0.7677, Test Loss: 0.7734, Train Accuracy: 0.7062, Test Accuracy: 0.7066
# Epoch 18/50, Train Loss: 0.7603, Test Loss: 0.7773, Train Accuracy: 0.7109, Test Accuracy: 0.6986
# Epoch 19/50, Train Loss: 0.7667, Test Loss: 0.7799, Train Accuracy: 0.7123, Test Accuracy: 0.6898
# Epoch 20/50, Train Loss: 0.7485, Test Loss: 0.7555, Train Accuracy: 0.7182, Test Accuracy: 0.7221
# Epoch 21/50, Train Loss: 0.7405, Test Loss: 0.7922, Train Accuracy: 0.7227, Test Accuracy: 0.6953
# Epoch 22/50, Train Loss: 0.7354, Test Loss: 0.7730, Train Accuracy: 0.7226, Test Accuracy: 0.7118
# Epoch 23/50, Train Loss: 0.7472, Test Loss: 0.7762, Train Accuracy: 0.7214, Test Accuracy: 0.7141
# Epoch 24/50, Train Loss: 0.7197, Test Loss: 0.7211, Train Accuracy: 0.7298, Test Accuracy: 0.7310
# Epoch 25/50, Train Loss: 0.7108, Test Loss: 0.7085, Train Accuracy: 0.7327, Test Accuracy: 0.7344
# Epoch 26/50, Train Loss: 0.7093, Test Loss: 0.7150, Train Accuracy: 0.7300, Test Accuracy: 0.7253
# Epoch 27/50, Train Loss: 0.6930, Test Loss: 0.7003, Train Accuracy: 0.7374, Test Accuracy: 0.7335
# Epoch 28/50, Train Loss: 0.6931, Test Loss: 0.7972, Train Accuracy: 0.7358, Test Accuracy: 0.7123
# Epoch 29/50, Train Loss: 0.7040, Test Loss: 0.7519, Train Accuracy: 0.7327, Test Accuracy: 0.7226
# Epoch 30/50, Train Loss: 0.6854, Test Loss: 0.7738, Train Accuracy: 0.7412, Test Accuracy: 0.7345
# Epoch 31/50, Train Loss: 0.6915, Test Loss: 0.7227, Train Accuracy: 0.7379, Test Accuracy: 0.7273
# Epoch 32/50, Train Loss: 0.6806, Test Loss: 0.7055, Train Accuracy: 0.7379, Test Accuracy: 0.7440
# Epoch 33/50, Train Loss: 0.6665, Test Loss: 0.6926, Train Accuracy: 0.7497, Test Accuracy: 0.7409
# Epoch 34/50, Train Loss: 0.6690, Test Loss: 0.7068, Train Accuracy: 0.7461, Test Accuracy: 0.7180
# Epoch 35/50, Train Loss: 0.6740, Test Loss: 0.7243, Train Accuracy: 0.7430, Test Accuracy: 0.7367
# Epoch 36/50, Train Loss: 0.6433, Test Loss: 0.6835, Train Accuracy: 0.7573, Test Accuracy: 0.7434
# Epoch 37/50, Train Loss: 0.6450, Test Loss: 0.6519, Train Accuracy: 0.7602, Test Accuracy: 0.7671
# Epoch 38/50, Train Loss: 0.6406, Test Loss: 0.6447, Train Accuracy: 0.7575, Test Accuracy: 0.7665
# Epoch 39/50, Train Loss: 0.6399, Test Loss: 0.6889, Train Accuracy: 0.7591, Test Accuracy: 0.7331
# Epoch 40/50, Train Loss: 0.6521, Test Loss: 0.6731, Train Accuracy: 0.7522, Test Accuracy: 0.7452
# Epoch 41/50, Train Loss: 0.6319, Test Loss: 0.6390, Train Accuracy: 0.7615, Test Accuracy: 0.7454
# Epoch 42/50, Train Loss: 0.6273, Test Loss: 0.6899, Train Accuracy: 0.7638, Test Accuracy: 0.7264
# Epoch 43/50, Train Loss: 0.6410, Test Loss: 0.6446, Train Accuracy: 0.7596, Test Accuracy: 0.7580
# Epoch 44/50, Train Loss: 0.6160, Test Loss: 0.6806, Train Accuracy: 0.7659, Test Accuracy: 0.7409
# Epoch 45/50, Train Loss: 0.6095, Test Loss: 0.6743, Train Accuracy: 0.7714, Test Accuracy: 0.7422
# Epoch 46/50, Train Loss: 0.6107, Test Loss: 0.6378, Train Accuracy: 0.7708, Test Accuracy: 0.7505
# Epoch 47/50, Train Loss: 0.6038, Test Loss: 0.6517, Train Accuracy: 0.7730, Test Accuracy: 0.7649
# Epoch 48/50, Train Loss: 0.6022, Test Loss: 0.6574, Train Accuracy: 0.7733, Test Accuracy: 0.7610
# Epoch 49/50, Train Loss: 0.5981, Test Loss: 0.6264, Train Accuracy: 0.7747, Test Accuracy: 0.7729
# Epoch 50/50, Train Loss: 0.6097, Test Loss: 0.6724, Train Accuracy: 0.7644, Test Accuracy: 0.7434
# Best accuracy: 0.7729211087420043
# 1. max_idle: 0.05279882997274399
# 2. flowBytesPerSecond: 0.0512065626680851
# 3. max_biat: 0.05015348270535469
# 4. total_biat: 0.046222489327192307
# 5. mean_flowiat: 0.04586534574627876
# 6. mean_active: 0.04556408151984215
# 7. mean_idle: 0.045216575264930725
# 8. min_biat: 0.04507560655474663
# 9. duration: 0.04413354769349098
# 10. total_fiat: 0.04342007637023926

# %%
#comparing with the feature importance ranking of sklearn's random forest

X = df.drop('class1', axis=1)
y = df['class1']

X_train, X_test, y_train, y_test =train_test_split(X, y, train_size=0.7, random_state=1)

rf = RandomForestClassifier(class_weight='balanced', max_depth=30,
                       max_features='log2', min_samples_leaf=2,
                       min_samples_split=5)

rf.fit(X_train, y_train)

yhat = rf.predict(X_test)

acc = accuracy_score(y_test, yhat)

print('accuracy:', acc)


best_features = rf.feature_importances_

# Get indices of top 10 features
top_indices = best_features.argsort()[-10:][::-1]

# Get corresponding feature names
feature_names = df.columns

# Display the top 10 features and their importances
for i, idx in enumerate(top_indices):
    print(f"{i+1}. {feature_names[idx]}: Importance {best_features[idx]}")
# Out:
# accuracy: 0.8880597014925373
# 1. flowBytesPerSecond: Importance 0.11835847718022968
# 2. duration: Importance 0.08389610785124893
# 3. total_biat: Importance 0.07120521998344786
# 4. min_flowiat: Importance 0.06585780418327875
# 5. total_fiat: Importance 0.060069962889214956
# 6. mean_fiat: Importance 0.05839502302566177
# 7. mean_flowiat: Importance 0.05668240396353497
# 8. max_flowiat: Importance 0.05621801484231171
# 9. flowPktsPerSecond: Importance 0.05511327182115652
# 10. min_fiat: Importance 0.05190480263940429

# %%
#No RFF, No aggregation, 1 encoder layer, no regularization. VERY BASIC


model = vpnClassifier(rff_on=False, num_layers=1, aggregation_on=False, heads=1).to(device_in_use)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(params=model.parameters(), lr=0.0001, momentum=0.9)

epochs = 500
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
all_attention_scores = []
for t in range(epochs):
  train_loss, train_accuracy= train(train_dataloader, model, loss_fn, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy = test(test_dataloader, model, loss_fn, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies.append(train_accuracy)
  test_losses.append(test_loss)
  test_accuracies.append(test_accuracy)
  print(f"Epoch {t+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}")
  

  total_attention = model.encoder.avg_attention
  all_attention_scores.append(total_attention.tolist())
  model.encoder.avg_attention = None


# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l.cpu().numpy() for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

plt.tight_layout()
plt.show()

print(f"Best accuracy: {max(test_accuracies)}")

# Plot attention scores for each feature over epochs

# all_attention_scores = all_attention_scores.cpu().numpy() #CUDA tensor needs to be converted to cpu tensor
all_attention_scores = torch.tensor(all_attention_scores)
plt.figure(figsize=(10, 6))



for feature_idx in range(all_attention_scores.shape[1]):
    plt.plot(all_attention_scores[:, feature_idx], label=df.drop("class1", axis=1).columns[feature_idx])

plt.xlabel('Epochs')
plt.ylabel('Attention Scores')
plt.title('Attention Scores for Each Feature over Epochs')
plt.legend(loc = 'lower left')
plt.show()

last_epoch_attention_scores = all_attention_scores[-1]
top_scores, top_indices = torch.topk(last_epoch_attention_scores, k=10)

# Display the top 10 attention scores and the corresponding feature
for i in range(10):
    print(f"{i+1}. {df.drop('class1', axis=1).columns[int(top_indices[i])]}: {top_scores[i]}")
# Out:
# Epoch 1/500, Train Loss: 1.6051, Test Loss: 1.1301, Train Accuracy: 0.4946, Test Accuracy: 0.6027
# Epoch 2/500, Train Loss: 1.0906, Test Loss: 1.0688, Train Accuracy: 0.6073, Test Accuracy: 0.6077
# Epoch 3/500, Train Loss: 1.0423, Test Loss: 1.0852, Train Accuracy: 0.6222, Test Accuracy: 0.5963
# Epoch 4/500, Train Loss: 1.0294, Test Loss: 1.0182, Train Accuracy: 0.6158, Test Accuracy: 0.6260
# Epoch 5/500, Train Loss: 0.9833, Test Loss: 0.9927, Train Accuracy: 0.6382, Test Accuracy: 0.6384
# Epoch 6/500, Train Loss: 0.9457, Test Loss: 0.9464, Train Accuracy: 0.6519, Test Accuracy: 0.6635
# Epoch 7/500, Train Loss: 0.9359, Test Loss: 0.9192, Train Accuracy: 0.6570, Test Accuracy: 0.6423
# Epoch 8/500, Train Loss: 0.8957, Test Loss: 0.9121, Train Accuracy: 0.6670, Test Accuracy: 0.6658
# Epoch 9/500, Train Loss: 0.8669, Test Loss: 0.8930, Train Accuracy: 0.6755, Test Accuracy: 0.6693
# Epoch 10/500, Train Loss: 0.8530, Test Loss: 0.8779, Train Accuracy: 0.6824, Test Accuracy: 0.6713
# Epoch 11/500, Train Loss: 0.8349, Test Loss: 0.8598, Train Accuracy: 0.6890, Test Accuracy: 0.6692
# Epoch 12/500, Train Loss: 0.8204, Test Loss: 0.8419, Train Accuracy: 0.6920, Test Accuracy: 0.6827
# Epoch 13/500, Train Loss: 0.8079, Test Loss: 0.8110, Train Accuracy: 0.6954, Test Accuracy: 0.7026
# Epoch 14/500, Train Loss: 0.7873, Test Loss: 0.8218, Train Accuracy: 0.7055, Test Accuracy: 0.6978
# Epoch 15/500, Train Loss: 0.7904, Test Loss: 0.7930, Train Accuracy: 0.7031, Test Accuracy: 0.6850
# Epoch 16/500, Train Loss: 0.7790, Test Loss: 0.7718, Train Accuracy: 0.7078, Test Accuracy: 0.7002
# Epoch 17/500, Train Loss: 0.7551, Test Loss: 0.7473, Train Accuracy: 0.7107, Test Accuracy: 0.7207
# Epoch 18/500, Train Loss: 0.7489, Test Loss: 0.7706, Train Accuracy: 0.7174, Test Accuracy: 0.7209
# Epoch 19/500, Train Loss: 0.7385, Test Loss: 0.7763, Train Accuracy: 0.7203, Test Accuracy: 0.7100
# Epoch 20/500, Train Loss: 0.7276, Test Loss: 0.7596, Train Accuracy: 0.7238, Test Accuracy: 0.7166
# Epoch 21/500, Train Loss: 0.7372, Test Loss: 0.7336, Train Accuracy: 0.7257, Test Accuracy: 0.7274
# Epoch 22/500, Train Loss: 0.7327, Test Loss: 0.7778, Train Accuracy: 0.7295, Test Accuracy: 0.7166
# Epoch 23/500, Train Loss: 0.7231, Test Loss: 0.7646, Train Accuracy: 0.7323, Test Accuracy: 0.7079
# Epoch 24/500, Train Loss: 0.7131, Test Loss: 0.7358, Train Accuracy: 0.7317, Test Accuracy: 0.7244
# Epoch 25/500, Train Loss: 0.6957, Test Loss: 0.7265, Train Accuracy: 0.7408, Test Accuracy: 0.7257
# Epoch 26/500, Train Loss: 0.6906, Test Loss: 0.7005, Train Accuracy: 0.7396, Test Accuracy: 0.7269
# Epoch 27/500, Train Loss: 0.6778, Test Loss: 0.7208, Train Accuracy: 0.7434, Test Accuracy: 0.7331
# Epoch 28/500, Train Loss: 0.6972, Test Loss: 0.7429, Train Accuracy: 0.7389, Test Accuracy: 0.7244
# Epoch 29/500, Train Loss: 0.6932, Test Loss: 0.7026, Train Accuracy: 0.7407, Test Accuracy: 0.7290
# Epoch 30/500, Train Loss: 0.6681, Test Loss: 0.6709, Train Accuracy: 0.7511, Test Accuracy: 0.7640
# Epoch 31/500, Train Loss: 0.6626, Test Loss: 0.6776, Train Accuracy: 0.7510, Test Accuracy: 0.7397
# Epoch 32/500, Train Loss: 0.6542, Test Loss: 0.6612, Train Accuracy: 0.7553, Test Accuracy: 0.7470
# Epoch 33/500, Train Loss: 0.6550, Test Loss: 0.6611, Train Accuracy: 0.7595, Test Accuracy: 0.7560
# Epoch 34/500, Train Loss: 0.6550, Test Loss: 0.6813, Train Accuracy: 0.7574, Test Accuracy: 0.7436
# Epoch 35/500, Train Loss: 0.6554, Test Loss: 0.6547, Train Accuracy: 0.7564, Test Accuracy: 0.7575
# Epoch 36/500, Train Loss: 0.6484, Test Loss: 0.6743, Train Accuracy: 0.7536, Test Accuracy: 0.7424
# Epoch 37/500, Train Loss: 0.6284, Test Loss: 0.6819, Train Accuracy: 0.7660, Test Accuracy: 0.7344
# Epoch 38/500, Train Loss: 0.6224, Test Loss: 0.6496, Train Accuracy: 0.7681, Test Accuracy: 0.7667
# Epoch 39/500, Train Loss: 0.6294, Test Loss: 0.6344, Train Accuracy: 0.7646, Test Accuracy: 0.7745
# Epoch 40/500, Train Loss: 0.6248, Test Loss: 0.6961, Train Accuracy: 0.7639, Test Accuracy: 0.7470
# Epoch 41/500, Train Loss: 0.6325, Test Loss: 0.6423, Train Accuracy: 0.7624, Test Accuracy: 0.7756
# Epoch 42/500, Train Loss: 0.6123, Test Loss: 0.6321, Train Accuracy: 0.7706, Test Accuracy: 0.7722
# Epoch 43/500, Train Loss: 0.6074, Test Loss: 0.6486, Train Accuracy: 0.7704, Test Accuracy: 0.7541
# Epoch 44/500, Train Loss: 0.6055, Test Loss: 0.6566, Train Accuracy: 0.7736, Test Accuracy: 0.7594
# Epoch 45/500, Train Loss: 0.6044, Test Loss: 0.6263, Train Accuracy: 0.7717, Test Accuracy: 0.7740
# Epoch 46/500, Train Loss: 0.5918, Test Loss: 0.6357, Train Accuracy: 0.7810, Test Accuracy: 0.7637
# Epoch 47/500, Train Loss: 0.5997, Test Loss: 0.6540, Train Accuracy: 0.7791, Test Accuracy: 0.7580
# Epoch 48/500, Train Loss: 0.5848, Test Loss: 0.6110, Train Accuracy: 0.7846, Test Accuracy: 0.7768
# Epoch 49/500, Train Loss: 0.5861, Test Loss: 0.6255, Train Accuracy: 0.7796, Test Accuracy: 0.7774
# Epoch 50/500, Train Loss: 0.5849, Test Loss: 0.6685, Train Accuracy: 0.7811, Test Accuracy: 0.7445
# Epoch 51/500, Train Loss: 0.5982, Test Loss: 0.6275, Train Accuracy: 0.7777, Test Accuracy: 0.7784
# Epoch 52/500, Train Loss: 0.5737, Test Loss: 0.5992, Train Accuracy: 0.7860, Test Accuracy: 0.7855
# Epoch 53/500, Train Loss: 0.5743, Test Loss: 0.6087, Train Accuracy: 0.7852, Test Accuracy: 0.7800
# Epoch 54/500, Train Loss: 0.5780, Test Loss: 0.7103, Train Accuracy: 0.7856, Test Accuracy: 0.7356
# Epoch 55/500, Train Loss: 0.5890, Test Loss: 0.6149, Train Accuracy: 0.7804, Test Accuracy: 0.7781
# Epoch 56/500, Train Loss: 0.5553, Test Loss: 0.6015, Train Accuracy: 0.7940, Test Accuracy: 0.7809
# Epoch 57/500, Train Loss: 0.5633, Test Loss: 0.6534, Train Accuracy: 0.7880, Test Accuracy: 0.7415
# Epoch 58/500, Train Loss: 0.5669, Test Loss: 0.6054, Train Accuracy: 0.7896, Test Accuracy: 0.7708
# Epoch 59/500, Train Loss: 0.5581, Test Loss: 0.5939, Train Accuracy: 0.7911, Test Accuracy: 0.7779
# Epoch 60/500, Train Loss: 0.5575, Test Loss: 0.6025, Train Accuracy: 0.7884, Test Accuracy: 0.7816
# Epoch 61/500, Train Loss: 0.5602, Test Loss: 0.6216, Train Accuracy: 0.7915, Test Accuracy: 0.7765
# Epoch 62/500, Train Loss: 0.5631, Test Loss: 0.6106, Train Accuracy: 0.7906, Test Accuracy: 0.7784
# Epoch 63/500, Train Loss: 0.5484, Test Loss: 0.6289, Train Accuracy: 0.7969, Test Accuracy: 0.7647
# Epoch 64/500, Train Loss: 0.5442, Test Loss: 0.5915, Train Accuracy: 0.7988, Test Accuracy: 0.7903
# Epoch 65/500, Train Loss: 0.5471, Test Loss: 0.5934, Train Accuracy: 0.7954, Test Accuracy: 0.7784
# Epoch 66/500, Train Loss: 0.5422, Test Loss: 0.5737, Train Accuracy: 0.7968, Test Accuracy: 0.7806
# Epoch 67/500, Train Loss: 0.5441, Test Loss: 0.5957, Train Accuracy: 0.7978, Test Accuracy: 0.7786
# Epoch 68/500, Train Loss: 0.5454, Test Loss: 0.5834, Train Accuracy: 0.7992, Test Accuracy: 0.7893
# Epoch 69/500, Train Loss: 0.5406, Test Loss: 0.5728, Train Accuracy: 0.7984, Test Accuracy: 0.7894
# Epoch 70/500, Train Loss: 0.5415, Test Loss: 0.6045, Train Accuracy: 0.7976, Test Accuracy: 0.7687
# Epoch 71/500, Train Loss: 0.5318, Test Loss: 0.5953, Train Accuracy: 0.8009, Test Accuracy: 0.7823
# Epoch 72/500, Train Loss: 0.5276, Test Loss: 0.5994, Train Accuracy: 0.8001, Test Accuracy: 0.7813
# Epoch 73/500, Train Loss: 0.5381, Test Loss: 0.6163, Train Accuracy: 0.7979, Test Accuracy: 0.7811
# Epoch 74/500, Train Loss: 0.5231, Test Loss: 0.6162, Train Accuracy: 0.8050, Test Accuracy: 0.7735
# Epoch 75/500, Train Loss: 0.5352, Test Loss: 0.5928, Train Accuracy: 0.7977, Test Accuracy: 0.7743
# Epoch 76/500, Train Loss: 0.5246, Test Loss: 0.5732, Train Accuracy: 0.8012, Test Accuracy: 0.7878
# Epoch 77/500, Train Loss: 0.5163, Test Loss: 0.5989, Train Accuracy: 0.8008, Test Accuracy: 0.7788
# Epoch 78/500, Train Loss: 0.5270, Test Loss: 0.5678, Train Accuracy: 0.8046, Test Accuracy: 0.7928
# Epoch 79/500, Train Loss: 0.5167, Test Loss: 0.5663, Train Accuracy: 0.8050, Test Accuracy: 0.7902
# Epoch 80/500, Train Loss: 0.5175, Test Loss: 0.5546, Train Accuracy: 0.8097, Test Accuracy: 0.7994
# Epoch 81/500, Train Loss: 0.5237, Test Loss: 0.5643, Train Accuracy: 0.8037, Test Accuracy: 0.8008
# Epoch 82/500, Train Loss: 0.5281, Test Loss: 0.5782, Train Accuracy: 0.8023, Test Accuracy: 0.7955
# Epoch 83/500, Train Loss: 0.5118, Test Loss: 0.5629, Train Accuracy: 0.8080, Test Accuracy: 0.8005
# Epoch 84/500, Train Loss: 0.5088, Test Loss: 0.5819, Train Accuracy: 0.8123, Test Accuracy: 0.7864
# Epoch 85/500, Train Loss: 0.5186, Test Loss: 0.5498, Train Accuracy: 0.8062, Test Accuracy: 0.8019
# Epoch 86/500, Train Loss: 0.5079, Test Loss: 0.5635, Train Accuracy: 0.8110, Test Accuracy: 0.7971
# Epoch 87/500, Train Loss: 0.5104, Test Loss: 0.6201, Train Accuracy: 0.8117, Test Accuracy: 0.7736
# Epoch 88/500, Train Loss: 0.5149, Test Loss: 0.5691, Train Accuracy: 0.8056, Test Accuracy: 0.7978
# Epoch 89/500, Train Loss: 0.5028, Test Loss: 0.5509, Train Accuracy: 0.8112, Test Accuracy: 0.8045
# Epoch 90/500, Train Loss: 0.4974, Test Loss: 0.5779, Train Accuracy: 0.8147, Test Accuracy: 0.7903
# Epoch 91/500, Train Loss: 0.4995, Test Loss: 0.5589, Train Accuracy: 0.8136, Test Accuracy: 0.7985
# Epoch 92/500, Train Loss: 0.4995, Test Loss: 0.5713, Train Accuracy: 0.8153, Test Accuracy: 0.7914
# Epoch 93/500, Train Loss: 0.5074, Test Loss: 0.5631, Train Accuracy: 0.8101, Test Accuracy: 0.7932
# Epoch 94/500, Train Loss: 0.4909, Test Loss: 0.5652, Train Accuracy: 0.8139, Test Accuracy: 0.7951
# Epoch 95/500, Train Loss: 0.4977, Test Loss: 0.5655, Train Accuracy: 0.8158, Test Accuracy: 0.7987
# Epoch 96/500, Train Loss: 0.4911, Test Loss: 0.5964, Train Accuracy: 0.8118, Test Accuracy: 0.7715
# Epoch 97/500, Train Loss: 0.5108, Test Loss: 0.5660, Train Accuracy: 0.8085, Test Accuracy: 0.8001
# Epoch 98/500, Train Loss: 0.4983, Test Loss: 0.5489, Train Accuracy: 0.8139, Test Accuracy: 0.8072
# Epoch 99/500, Train Loss: 0.4829, Test Loss: 0.5718, Train Accuracy: 0.8190, Test Accuracy: 0.7955
# Epoch 100/500, Train Loss: 0.4942, Test Loss: 0.5566, Train Accuracy: 0.8097, Test Accuracy: 0.7918
# Epoch 101/500, Train Loss: 0.4942, Test Loss: 0.5449, Train Accuracy: 0.8157, Test Accuracy: 0.7962
# Epoch 102/500, Train Loss: 0.4875, Test Loss: 0.5437, Train Accuracy: 0.8165, Test Accuracy: 0.8111
# Epoch 103/500, Train Loss: 0.4766, Test Loss: 0.5392, Train Accuracy: 0.8217, Test Accuracy: 0.8021
# Epoch 104/500, Train Loss: 0.4909, Test Loss: 0.5714, Train Accuracy: 0.8183, Test Accuracy: 0.7898
# Epoch 105/500, Train Loss: 0.4811, Test Loss: 0.5627, Train Accuracy: 0.8189, Test Accuracy: 0.7966
# Epoch 106/500, Train Loss: 0.4845, Test Loss: 0.5850, Train Accuracy: 0.8166, Test Accuracy: 0.7976
# Epoch 107/500, Train Loss: 0.4978, Test Loss: 0.5976, Train Accuracy: 0.8128, Test Accuracy: 0.7950
# Epoch 108/500, Train Loss: 0.4882, Test Loss: 0.5612, Train Accuracy: 0.8193, Test Accuracy: 0.7974
# Epoch 109/500, Train Loss: 0.5065, Test Loss: 0.5458, Train Accuracy: 0.8136, Test Accuracy: 0.7964
# Epoch 110/500, Train Loss: 0.4886, Test Loss: 0.5723, Train Accuracy: 0.8146, Test Accuracy: 0.7951
# Epoch 111/500, Train Loss: 0.4790, Test Loss: 0.5517, Train Accuracy: 0.8206, Test Accuracy: 0.8001
# Epoch 112/500, Train Loss: 0.4757, Test Loss: 0.5409, Train Accuracy: 0.8206, Test Accuracy: 0.7976
# Epoch 113/500, Train Loss: 0.4662, Test Loss: 0.5557, Train Accuracy: 0.8224, Test Accuracy: 0.7974
# Epoch 114/500, Train Loss: 0.4793, Test Loss: 0.5510, Train Accuracy: 0.8204, Test Accuracy: 0.8042
# Epoch 115/500, Train Loss: 0.4750, Test Loss: 0.5280, Train Accuracy: 0.8260, Test Accuracy: 0.8147
# Epoch 116/500, Train Loss: 0.4672, Test Loss: 0.5587, Train Accuracy: 0.8241, Test Accuracy: 0.7971
# Epoch 117/500, Train Loss: 0.4779, Test Loss: 0.5391, Train Accuracy: 0.8200, Test Accuracy: 0.8044
# Epoch 118/500, Train Loss: 0.4654, Test Loss: 0.5989, Train Accuracy: 0.8240, Test Accuracy: 0.7795
# Epoch 119/500, Train Loss: 0.4714, Test Loss: 0.5861, Train Accuracy: 0.8203, Test Accuracy: 0.7877
# Epoch 120/500, Train Loss: 0.4690, Test Loss: 0.5542, Train Accuracy: 0.8262, Test Accuracy: 0.7985
# Epoch 121/500, Train Loss: 0.4696, Test Loss: 0.5434, Train Accuracy: 0.8249, Test Accuracy: 0.8067
# Epoch 122/500, Train Loss: 0.4740, Test Loss: 0.5633, Train Accuracy: 0.8193, Test Accuracy: 0.7884
# Epoch 123/500, Train Loss: 0.4624, Test Loss: 0.5443, Train Accuracy: 0.8284, Test Accuracy: 0.8081
# Epoch 124/500, Train Loss: 0.4612, Test Loss: 0.5236, Train Accuracy: 0.8271, Test Accuracy: 0.8147
# Epoch 125/500, Train Loss: 0.4637, Test Loss: 0.5396, Train Accuracy: 0.8276, Test Accuracy: 0.8072
# Epoch 126/500, Train Loss: 0.4551, Test Loss: 0.5264, Train Accuracy: 0.8290, Test Accuracy: 0.8120
# Epoch 127/500, Train Loss: 0.4605, Test Loss: 0.5457, Train Accuracy: 0.8292, Test Accuracy: 0.8033
# Epoch 128/500, Train Loss: 0.4634, Test Loss: 0.5597, Train Accuracy: 0.8251, Test Accuracy: 0.7973
# Epoch 129/500, Train Loss: 0.4611, Test Loss: 0.5555, Train Accuracy: 0.8239, Test Accuracy: 0.8040
# Epoch 130/500, Train Loss: 0.4515, Test Loss: 0.5642, Train Accuracy: 0.8325, Test Accuracy: 0.7971
# Epoch 131/500, Train Loss: 0.4594, Test Loss: 0.5300, Train Accuracy: 0.8256, Test Accuracy: 0.8092
# Epoch 132/500, Train Loss: 0.4539, Test Loss: 0.5669, Train Accuracy: 0.8293, Test Accuracy: 0.7973
# Epoch 133/500, Train Loss: 0.4567, Test Loss: 0.5345, Train Accuracy: 0.8260, Test Accuracy: 0.8014
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 15
#      13 all_attention_scores = []
#      14 for t in range(epochs):
# ---> 15   train_loss, train_accuracy= train(train_dataloader, model, loss_fn, optimizer, device_in_use=device_in_use)
#      16   test_loss, test_accuracy = test(test_dataloader, model, loss_fn, device_in_use=device_in_use)
#      17   train_losses.append(train_loss)
#
# Cell In[19], line 24, in train(dataloader, model, loss_fn, optimizer, device_in_use)
#      21 total_correct += (y_pred_labels == targets).sum().item()
#      22 total_samples += targets.size(0)
# ---> 24 loss.backward()
#      25 optimizer.step()
#      26 optimizer.zero_grad()
#
# File c:\Users\irworkstudy\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File c:\Users\irworkstudy\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
